# %% [markdown]
# <a href="https://colab.research.google.com/github/nehadacherla/skills-introduction-to-github/blob/main/DataViz_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib as plt
import pandas as pd

# %%
hulu = pd.read_csv('/content/data.csv')
hulu.head()
# Out:
#                  title   type                     genres  releaseYear  \
# 0                Ariel  movie     Comedy, Crime, Romance       1988.0
# 1  Shadows in Paradise  movie       Comedy, Drama, Music       1986.0
# 2         Forrest Gump  movie             Drama, Romance       1994.0
# 3    The Fifth Element  movie  Action, Adventure, Sci-Fi       1997.0
# 4   My Life Without Me  movie             Drama, Romance       2003.0
#
#       imdbId  imdbAverageRating  imdbNumVotes availableCountries
# 0  tt0094675                7.4        8776.0                 JP
# 1  tt0092149                7.5        7538.0                 JP
# 2  tt0109830                8.8     2320505.0                 JP
# 3  tt0119116                7.6      517631.0                 JP
# 4  tt0314412                7.4       26044.0                 JP

# %%
import seaborn as sns
sns.scatterplot(hulu, x='imdbAverageRating', y='imdbNumVotes', s=32, alpha=.8, hue='availableCountries')
plt.title('Scatter Plot of IMDB Ratings vs. Number of Votes by Available Country')
plt.xlabel('IMDB Rating')
plt.ylabel('Number of Votes')
# Out:
# Text(0, 0.5, 'Number of Votes')

# %%
numeric_hulu = hulu.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_hulu.corr()

# Create a heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Hulu imdb Votes, Rating, and Release Year')
plt.show()

# %%
hulu['genres'] = hulu['genres'].str.split(',').str[0]

# %%
hulu['genres'].unique()
# Out:
# array(['Comedy', 'Drama', 'Action', 'Mystery', 'Adventure', 'Crime',
#        'Horror', 'Biography', 'Documentary', 'Fantasy', 'Animation',
#        'Romance', 'Thriller', nan, 'Music', 'Short', 'Sci-Fi',
#        'Science Fiction', 'Family', 'War', 'Sport', 'Musical', 'History',
#        'News', 'TV Movie', 'Reality-TV', 'Game-Show', 'Talk-Show',
#        'Action & Adventure', 'Soap', 'Reality', 'Sci-Fi & Fantasy',
#        'Kids'], dtype=object)

# %%
import plotly.express as px
import pandas as pd

# Create an interactive scatter plot
fig = px.scatter(
    hulu,
    x='imdbAverageRating',
    y='imdbNumVotes',
    color='genres',
    animation_frame='releaseYear',  # Animate over years
    title='Scatter Plot of IMDB Ratings vs. Number of Votes',
    labels={'imdbAverageRating': 'IMDB Rating', 'imdbNumVotes': 'Number of Votes'},
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ede8a1b4-6d63-4710-a31e-87c0be24f7cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ede8a1b4-6d63-4710-a31e-87c0be24f7cf")) {                    Plotly.newPlot(                        "ede8a1b4-6d63-4710-a31e-87c0be24f7cf",                        [{"hovertemplate":"genres=Comedy\u003cbr\u003ereleaseYear=1988.0\u003cbr\u003eIMDB Rating=%{x}\u003cbr\u003eNumber of Votes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Comedy","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Comedy","orientation":"v","showlegend":true,"x":[7.4,7.3,7.5,7.5,5.8,7.0,6.4,8.4],"xaxis":"x","y":[8776.0,245541.0,390268.0,47632.0,2399.0,69.0,70.0,41636.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"genres=Drama\u003cbr\u003ereleaseYear=1988.0\u003cbr\u003eIMDB Rating=%{x}\u003cbr\u003eNumber of Votes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Drama","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Drama","orientation":"v","showlegend":true,"x":[7.1,6.9,6.6,7.3],"xaxis":"x","y":[549.0,309.0,65.0,97.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"genres=Action\u003cbr\u003ereleaseYear=1988.0\u003cbr\u003eIMDB Rating=%{x}\u003cbr\u003eNumber of Votes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Action","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Action","orientation":"v","showlegend":true,"x":[8.0,8.2,6.3,7.1,7.1,5.5,6.4,6.8,6.2,6.0,6.0,5.9,5.5,null,7.4,7.8],"xaxis":"x","y":[210805.0,963814.0,50065.0,23225.0,9635.0,123.0,155.0,2789.0,261.0,245.0,86.0,38.0,41.0,null,152.0,90.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"genres=Adventure\u003cbr\u003ereleaseYear=1988.0\u003cbr\u003eIMDB Rating=%{x}\u003cbr\u003eNumber of Votes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Adventure","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Adventure","orientation":"v","showlegend":true,"x":[7.4],"xaxis":"x","y":[14335.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"genres=Horror\u003cbr\u003ereleaseYear=1988.0\u003cbr\u003eIMDB Rating=%{x}\u003cbr\u003eNumber of Votes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Horror","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Horror","orientation":"v","showlegend":true,"x":[6.4,6.7],"xaxis":"x","y":[57629.0,122179.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"genres=Animation\u003cbr\u003ereleaseYear=1988.0\u003cbr\u003eIMDB Rating=%{x}\u003cbr\u003eNumber of Votes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Animation","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Animation","orientation":"v","showlegend":true,"x":[null,null,7.9,7.2],"xaxis":"x","y":[null,null,34.0,12.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0 ...
