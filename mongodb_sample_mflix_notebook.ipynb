# %% [markdown]
# <a href="https://colab.research.google.com/github/nehadacherla/skills-introduction-to-github/blob/main/mongodb_sample_mflix_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MongoDB Atlas with Python: Using the `sample_mflix` Dataset
# This notebook introduces the basics of querying, filtering, and performing aggregations with MongoDB using the **sample_mflix** dataset. The dataset contains movie-related information such as movies, comments, theaters, and users. You'll learn how to:
# - Connect to MongoDB Atlas
# - Perform basic queries and filtering
# - Execute advanced operations like aggregation
# - Create indexes and update/delete documents
#
# Let's get started!

# %%
# !pip install --upgrade pymongo certifi
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (2024.8.30)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 5.7 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 14.4 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.10.1

# %% [markdown]
# ## 1. Setup and Connection to MongoDB Atlas

# %%
# Install pymongo for MongoDB connection


# Import necessary libraries
from pymongo import MongoClient
import pprint

# Replace with your MongoDB Atlas connection string
connection_string = "mongodb+srv://nehadacherla:Elephant444@ndcluster.nqvkw.mongodb.net/?retryWrites=true&w=majority&appName=NDCluster"

# Connect to MongoDB Atlas
client = MongoClient(connection_string)

# Access the sample_mflix database and the movies collection
db = client['sample_mflix']
collection = db['movies']
print(collection.find_one())
# Out:
# {'_id': ObjectId('573a1393f29313caabcdcb42'), 'plot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her ex-boyfriend, Stuart, lives above her apartment. Stuart finds a space near the Brooklyn Bridge where there is a gap in time....', 'genres': ['Comedy', 'Fantasy', 'Romance'], 'runtime': 118, 'metacritic': 44, 'rated': 'PG-13', 'cast': ['Meg Ryan', 'Hugh Jackman', 'Liev Schreiber', 'Breckin Meyer'], 'poster': 'https://m.media-amazon.com/images/M/MV5BNmNlN2VlOTctYTdhMS00NzUxLTg0ZGMtYWE2ZTJmMThlMTk2XkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_SY1000_SX677_AL_.jpg', 'title': 'Kate & Leopold', 'fullplot': "Kate and her actor brother live in N.Y. in the 21st Century. Her ex-boyfriend, Stuart, lives above her apartment. Stuart finds a space near the Brooklyn Bridge where there is a gap in time. He goes back to the 19th Century and takes pictures of the place. Leopold -- a man living in the 1870s -- is puzzled by Stuart's tiny camera, follows him back through the gap, and they both ended up in the present day. Leopold is clueless about his new surroundings. He gets help and insight from Charlie who thinks that Leopold is an actor who is always in character. Leopold is a highly intelligent man and tries his best to learn and even improve the modern conveniences that he encounters.", 'languages': ['English', 'French'], 'released': datetime.datetime(2001, 12, 25, 0, 0), 'directors': ['James Mangold'], 'writers': ['Steven Rogers (story)', 'James Mangold (screenplay)', 'Steven Rogers (screenplay)'], 'awards': {'wins': 2, 'nominations': 4, 'text': 'Nominated for 1 Oscar. Another 1 win & 4 nominations.'}, 'lastupdated': '2015-08-31 00:19:09.717000000', 'year': 2001, 'imdb': {'rating': 6.3, 'votes': 59951, 'id': 35423}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'website': 'http://www.kateandleopold-themovie.com', 'viewer': {'rating': 3.0, 'numReviews': 189426, 'meter': 62}, 'dvd': datetime.datetime(2002, 6, 11, 0, 0), 'critic': {'rating': 5.3, 'numReviews': 126, 'meter': 50}, 'boxOffice': '$47.1M', 'consensus': 'Though Jackman charms, Kate and Leopold is bland and predictable, and the time travel scenario lacks inner logic.', 'rotten': 63, 'production': 'Miramax Films', 'lastUpdated': datetime.datetime(2015, 8, 22, 18, 53, 25), 'fresh': 63}, 'num_mflix_comments': 0}

# %% [markdown]
# ## 2. Basic MongoDB Commands
# ### Searching for Documents (Basic Query)

# %%
# Find one document from the movies collection
document = collection.find_one()
pprint.pprint(document)
# Out:
# {'_id': ObjectId('573a1390f29313caabcd4eaf'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Jane Gail', 'Ethel Grandin', 'William H. Turner', 'Matt Moore'],
#  'countries': ['USA'],
#  'directors': ['George Loane Tucker'],
#  'genres': ['Crime', 'Drama'],
#  'imdb': {'id': 3471, 'rating': 6.0, 'votes': 371},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 02:07:14.247000000',
#  'num_mflix_comments': 1,
#  'plot': 'A woman, with the aid of her police officer sweetheart, endeavors to '
#          'uncover the prostitution ring that has kidnapped her sister, and the '
#          'philanthropist who secretly runs it.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYzk0YWQzMGYtYTM5MC00NjM2LWE5YzYtMjgyNDVhZDg1N2YzXkEyXkFqcGdeQXVyMzE0MjY5ODA@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-PG',
#  'released': datetime.datetime(1913, 11, 24, 0, 0),
#  'runtime': 88,
#  'title': 'Traffic in Souls',
#  'tomatoes': {'dvd': datetime.datetime(2008, 8, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 10, 18, 33, 55),
#               'viewer': {'meter': 57, 'numReviews': 85, 'rating': 3.0}},
#  'type': 'movie',
#  'year': 1913}

# %% [markdown]
# ### Searching with a Filter (Filtering)

# %%
# Find all movies where the genre contains "Action"
action_movies = collection.find({"genres": "Action"}).limit(5)

# Print the results
for movie in action_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1391f29313caabcd8319'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Harold Lloyd', 'Jobyna Ralston', 'Noah Young', 'Jim Mason'],
#  'countries': ['USA'],
#  'directors': ['Sam Taylor'],
#  'fullplot': 'The Uptown Boy, J. Harold Manners (Lloyd) is a millionaire '
#              'playboy who falls for the Downtown Girl, Hope (Ralston) who '
#              "works in Brother Paul's (Weigel) mission. In order to build up "
#              "attendance, and win Hope's attention, Harold runs through town "
#              'causing trouble, and winds up with a crowd chasing him right '
#              'into the mission. He eventually wins the girl and they marry, '
#              'but not without some interference from his high-brow friends.',
#  'genres': ['Action', 'Comedy', 'Romance'],
#  'imdb': {'id': 16895, 'rating': 7.6, 'votes': 918},
#  'languages': ['English'],
#  'lastupdated': '2015-08-19 00:35:01.953000000',
#  'num_mflix_comments': 0,
#  'plot': 'An irresponsible young millionaire changes his tune when he falls '
#          'for the daughter of a downtown minister.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTcxMTEwMTIzNl5BMl5BanBnXkFtZTgwMzYzODYwMjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1926, 4, 5, 0, 0),
#  'runtime': 58,
#  'title': "For Heaven's Sake",
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 6, 18, 7, 59),
#               'production': 'Paramount Studios',
#               'viewer': {'meter': 92, 'numReviews': 87, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Ted Wilde (story)',
#              'John Grey (story)',
#              'Clyde Bruckman (story)',
#              'Ralph Spence (titles)'],
#  'year': 1926}
# {'_id': ObjectId('573a1391f29313caabcd8268'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Billie Dove', 'Tempe Pigott', 'Donald Crisp', 'Sam De Grasse'],
#  'countries': ['USA'],
#  'directors': ['Albert Parker'],
#  'fullplot': 'A nobleman vows to avenge the death of his father at the hands '
#              'of pirates. To this end he infiltrates the pirate band. Acting '
#              'in character he is instrumental in the capture of a ship, but '
#              'things are complicated when he finds that there is a young woman '
#              'on board whom he wishes to protect from the threat of rape.',
#  'genres': ['Adventure', 'Action'],
#  'imdb': {'id': 16654, 'rating': 7.2, 'votes': 1146},
#  'lastupdated': '2015-08-22 01:10:11.970000000',
#  'num_mflix_comments': 1,
#  'plot': 'Seeking revenge, an athletic young man joins the pirate band '
#          "responsible for his father's death.",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMzU0NDkyMjEzMV5BMl5BanBnXkFtZTgwMTcyMzEyMjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1926, 3, 8, 0, 0),
#  'runtime': 88,
#  'title': 'The Black Pirate',
#  'tomatoes': {'critic': {'meter': 100, 'numReviews': 9, 'rating': 8.1},
#               'dvd': datetime.datetime(1999, 10, 12, 0, 0),
#               'fresh': 9,
#               'lastUpdated': datetime.datetime(2015, 7, 22, 19, 23, 50),
#               'rotten': 0,
#               'viewer': {'meter': 70, 'numReviews': 1390, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Douglas Fairbanks (story)', 'Jack Cunningham (adapted by)'],
#  'year': 1926}
# {'_id': ObjectId('573a1391f29313caabcd68d0'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Harold Lloyd',
#           'Mildred Davis',
#           "'Snub' Pollard",
#           'Peggy Cartwright'],
#  'countries': ['USA'],
#  'directors': ['Alfred J. Goulding', 'Hal Roach'],
#  'fullplot': 'As a penniless man worries about how he will manage to eat, he '
#              'is joined by a young waif and her dog, who are in the same '
#              'predicament. Meanwhile, across town a dishonest lawyer is '
#              'working with a gang of criminals, trying to swindle an innocent '
#              'young heiress out of her inheritance. As the heiress is on her '
#              "way home from the lawyer's office, she notices the young man and "
#              'the waif in the midst of their latest problem with the '
#              'authorities, and she rescues them. Later on, the young man will '
#              'have an unexpected opportunity to repay her for her kindness.',
#  'genres': ['Comedy', 'Short', 'Action'],
#  'imdb': {'id': 10146, 'rating': 7.0, 'votes': 639},
#  'languages': ['English'],
#  'lastupdated': '2015-04-17 00:16:14.220000000',
#  'num_mflix_comments': 0,
#  'plot': 'A penniless young man tries to save an heiress from kidnappers and '
#          'help her secure her inheritance.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzE1OWRlNDgtMTllNi00NTZiLWIyNTktYTk0MDY1ZWUwYTc5XkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-G',
#  'released': datetime.datetime(1919, 12, 28, 0, 0),
#  'runtime': 22,
#  'title': 'From Hand to Mouth',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 21, 18, 45, 11),
#               'production': 'Pathè Exchange',
#               'viewer': {'meter': 55, 'numReviews': 71, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['H.M. Walker (titles)'],
#  'year': 1919}
# {'_id': ObjectId('573a1390f29313caabcd5293'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Pearl White', 'Crane Wilbur', 'Paul Panzer', 'Edward Josè'],
#  'countries': ['USA'],
#  'directors': ['Louis J. Gasnier', 'Donald MacKenzie'],
#  'fullplot': 'Young Pauline is left a lot of money when her wealthy uncle '
#              "dies. However, her uncle's secretary has been named as her "
#              'guardian until she marries, at which time she will officially '
#              'take possession of her inheritance. Meanwhile, her "guardian" '
#              'and his confederates constantly come up with schemes to get rid '
#              'of Pauline so that he can get his hands on the money himself.',
#  'genres': ['Action'],
#  'imdb': {'id': 4465, 'rating': 7.6, 'votes': 744},
#  'languages': ['English'],
#  'lastupdated': '2015-09-12 00:01:18.647000000',
#  'num_mflix_comments': 0,
#  'plot': 'Young Pauline is left a lot of money when her wealthy uncle dies. '
#          "However, her uncle's secretary has been named as her guardian until "
#          'she marries, at which time she will officially take ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMzgxODk1Mzk2Ml5BMl5BanBnXkFtZTgwMDg0NzkwMjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1914, 3, 23, 0, 0),
#  'runtime': 199,
#  'title': 'The Perils of Pauline',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 11, 17, 46, 19),
#               'production': 'Pathè Frères',
#               'viewer': {'numReviews': 9, 'rating': 2.8}},
#  'type': 'movie',
#  'writers': ['Charles W. Goddard (screenplay)',
#              'Basil Dickey (screenplay)',
#              'Charles W. Goddard (novel)',
#              'George B. Seitz',
#              'Bertram Millhauser'],
#  'year': 1914}
# {'_id': ObjectId('573a1391f29313caabcd820b'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Ronald Colman', 'Neil Hamilton', 'Ralph Forbes', 'Alice Joyce'],
#  'countries': ['USA'],
#  'directors': ['Herbert Brenon'],
#  'fullplot': 'Michael "Beau" Geste leaves England in disgrace and joins the '
#              'infamous French Foreign Legion. He is reunited with his two '
#              'brothers in North Africa, where they face greater danger from '
#              'their own sadistic commander than from the rebellious Arabs.',
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 16634, 'rating': 6.9, 'votes': 222},
#  'languages': ['English'],
#  'lastupdated': '2015-08-25 00:40:54.383000000',
#  'num_mflix_comments': 0,
#  'plot': 'Michael "Beau" Geste leaves England in disgrace and joins the '
#          'infamous French Foreign Legion. He is reunited with his two brothers '
#          'in North Africa, where they face greater danger from their...',
#  'released': datetime.datetime(1926, 8, 25, 0, 0),
#  'runtime': 101,
#  'title': 'Beau Geste',
#  'tomatoes': {'dvd': datetime.datetime(2000, 3, 28, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 4, 18, 18, 16, 4),
#               'viewer': {'meter': 38, 'numReviews': 75, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Herbert Brenon (adaptation)',
#              'John Russell (adaptation)',
#              'Paul Schofield',
#              'Percival Christopher Wren (novel)'],
#  'year': 1926}

# %% [markdown]
# ### Sorting Results

# %%
# Find and sort movies by release year in descending order
sorted_movies = collection.find().sort("year", -1).limit(5)

# Print the sorted results
for movie in sorted_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13eaf29313caabdcfbc1'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 2 Primetime Emmys. Another 1 win & 4 '
#                     'nominations.',
#             'wins': 3},
#  'cast': ['Meryl Streep',
#           'Edward Herrmann',
#           'Doris Kearns Goodwin',
#           'Franklin D. Roosevelt'],
#  'countries': ['USA'],
#  'fullplot': 'A documentary that weaves together the stories of Theodore, '
#              'Franklin and Eleanor Roosevelt, three members of one of the most '
#              'prominent and influential families in American politics.',
#  'genres': ['Documentary'],
#  'imdb': {'id': 3400010, 'rating': 8.8, 'votes': 682},
#  'languages': ['English'],
#  'lastupdated': '2015-08-23 00:10:24.657000000',
#  'num_mflix_comments': 1,
#  'plot': 'A documentary that weaves together the stories of Theodore, Franklin '
#          'and Eleanor Roosevelt, three members of one of the most prominent '
#          'and influential families in American politics.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMDNlZWM2MDUtOWRlYi00MGQ3LTgxOGEtY2UxYmMwYjIxYWYxXkEyXkFqcGdeQXVyMjExMjk0ODk@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 9, 14, 0, 0),
#  'title': 'The Roosevelts: An Intimate History',
#  'type': 'series',
#  'year': '2014è'}
# {'_id': ObjectId('573a13f1f29313caabddc613'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Steven Waddington',
#           'Siennah Buck',
#           'Mike Colter',
#           'Christian Contreras'],
#  'fullplot': 'In the 28th Century, the prolonged war between humanity and the '
#              'fanatical alien alliance the Covenant has ended with a tenuous '
#              "treaty. Despite the ceasefire, Earth's outer colonies remain "
#              "vulnerable to the Covenant's covert intrusions. The ONI - Office "
#              'of Naval Intelligence has been tasked with counterintelligence '
#              'to beat the Covenant. In Planet Sedra, Commander Jameson Locke '
#              "and his team witness a Covenant's spacecraft and a Zealot Elite "
#              'warrior disembarks with a bomb. They unsuccessfully try to stop '
#              'the alien that explodes the bomb in a mall. They realize that it '
#              'is a biological attack with an element fatal to humans. Sedran '
#              'Commander Aiken captures the middleman Axl that tells that the '
#              'element is obtained from Alpha Halo, where the day longs 16 h '
#              'and the temperature in the sunlight reaches 482o C. Aiken, Locke '
#              'and his team head to Halo in the spacecraft Condor with pilot '
#              'Macer carrying a Havoc weapon to destroy the place. On the '
#              'arrival, they find two terrorists but are trapped in Halo by '
#              'weird worms that are attracted by technology. And in five hours '
#              'the sun will rise.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 3804114, 'rating': 5.7, 'votes': 2640},
#  'languages': ['English'],
#  'lastupdated': '2015-08-20 00:40:26.313000000',
#  'num_mflix_comments': 0,
#  'plot': 'While investigating terrorist activity on the distant colony world '
#          'of Sedra, Jameson Locke and his team are caught in a horrific '
#          'biological attack that exposes them to a much deeper danger.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2NTQwNzU2OV5BMl5BanBnXkFtZTgwNzkxOTQ0MzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 11, 11, 0, 0),
#  'runtime': 30,
#  'title': 'Halo: Nightfall',
#  'type': 'series',
#  'year': '2014è'}
# {'_id': ObjectId('573a13dbf29313caabdae27b'),
#  'awards': {'nominations': 3,
#             'text': 'Nominated for 1 Primetime Emmy. Another 2 nominations.',
#             'wins': 0},
#  'cast': ['Cindy Roach',
#           'Gerald Berenson',
#           'Peter Katzmarzyk',
#           'Stephanie Broyles'],
#  'countries': ['USA'],
#  'genres': ['Documentary'],
#  'imdb': {'id': 2327631, 'rating': 7.4, 'votes': 86},
#  'languages': ['English', 'Spanish'],
#  'lastupdated': '2015-07-31 00:04:27.097000000',
#  'num_mflix_comments': 0,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ3NjExNzk3Ml5BMl5BanBnXkFtZTgwMjYyNTAxMzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2012, 5, 14, 0, 0),
#  'title': 'The Weight of the Nation',
#  'tomatoes': {'critic': {'meter': 88, 'numReviews': 8, 'rating': 8.8},
#               'fresh': 7,
#               'lastUpdated': datetime.datetime(2015, 8, 18, 19, 35, 13),
#               'production': 'HBO',
#               'rotten': 1,
#               'viewer': {'numReviews': 23, 'rating': 4.2},
#               'website': 'http://theweightofthenation.hbo.com/films/bonus-shorts/the-quest-to-understand-t'},
#  'type': 'series',
#  'year': '2012è'}
# {'_id': ObjectId('573a13d9f29313caabda87b7'),
#  'awards': {'nominations': 3, 'text': '3 nominations.', 'wins': 0},
#  'cast': ['Jonas Armstrong', 'Chloè Sevigny', 'Karla Crome', 'Reece Noi'],
#  'countries': ['UK'],
#  'fullplot': 'Follows the life of transgender contract killer Mia, who travels '
#              'to West Yorkshire to seek out her ex girlfriend.',
#  'genres': ['Drama'],
#  'imdb': {'id': 2232345, 'rating': 7.9, 'votes': 3747},
#  'languages': ['English'],
#  'lastupdated': '2015-08-27 00:12:50.697000000',
#  'num_mflix_comments': 2,
#  'plot': 'Follows the life of transgender contract killer Mia, who travels to '
#          'West Yorkshire to seek out her ex girlfriend.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BOWFiZjBmOWItMDVjYi00ZjI0LTgzODgtMmFkMTdlNDVmODY3XkEyXkFqcGdeQXVyMjM2Mzk0MDk@._V1_SY1000_SX677_AL_.jpg',
#  'title': 'Hit & Miss',
#  'type': 'series',
#  'writers': ['Paul Abbott'],
#  'year': '2012è'}
# {'_id': ObjectId('573a13d5f29313caabd9d89c'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Hazuki Kimura', 'Manatsu Kimura', 'Kyèko Koizumi', 'Asumi Kikuchi'],
#  'countries': ['Japan'],
#  'fullplot': 'The murder of Emili, a young girl, leaves the inhabitants of a '
#              'small Japanese village in shock. The body of Emily is found by '
#              'the four classmates with whom she was playing. The murder is '
#              "never solved. Emili's mother Asako (Kyoko Koizumi) is torn by "
#              'grief and puts a curse on the four girls when they claim that '
#              "they don't remember the killer's face. Each of the girls, in "
#              'their own way, will do their penance for their silence. Deeply '
#              'struck by the words of Asako and burdened with her curse, the '
#              'four girls are forced into adulthood which eventually triggers a '
#              'tragic chain of events.',
#  'genres': ['Mystery'],
#  'imdb': {'id': 2043616, 'rating': 7.2, 'votes': 570},
#  'languages': ['Japanese'],
#  'lastupdated': '2015-08-27 00:20:32.947000000',
#  'metacritic': 58,
#  'num_mflix_comments': 0,
#  'plot': 'The murder of Emili, a young girl, leaves the inhabitants of a small '
#          'Japanese village in shock. The body of Emily is found by the four '
#          'classmates with whom she was playing. The murder is ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc0MDI0NTczMl5BMl5BanBnXkFtZTgwOTQyMTc5MjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2012, 1, 8, 0, 0),
#  'runtime': 270,
#  'title': 'Penance',
#  'tomatoes': {'critic': {'meter': 80, 'numReviews': 5, 'rating': 5.7},
#               'dvd': datetime.datetime(2009, 11, 17, 0, 0),
#               'fresh': 4,
#               'lastUpdated': datetime.datetime(2015, 7, 26, 18, 0, 11),
#               'production': 'Doppelgènger Releasing',
#               'rotten': 1,
#               'viewer': {'meter': 16, 'numReviews': 292, 'rating': 2.1},
#               'website': 'http://www.musicboxfilms.com/penance'},
#  'type': 'series',
#  'year': '2012è'}

# %% [markdown]
# ### Searching with Multiple Conditions

# %%
# Find movies where the genre is "Action" and the rating is greater than 8
multi_condition_query = {"genres": "Action", "imdb.rating": {"$gt": 8}}

# Execute the query
results = collection.find(multi_condition_query).limit(5)

# Print the results
for result in results:
    pprint.pprint(result)
# Out:
# {'_id': ObjectId('573a1395f29313caabce2498'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Clint Eastwood',
#           'Marianne Koch',
#           'Gian Maria Volontè',
#           'Wolfgang Lukschy'],
#  'countries': ['Italy', 'Spain', 'West Germany'],
#  'directors': ['Sergio Leone'],
#  'fullplot': 'An anonymous, but deadly man rides into a town torn by war '
#              "between two factions, the Baxters and the Rojo's. Instead of "
#              'fleeing or dying, as most other would do, the man schemes to '
#              'play the two sides off each other, getting rich in the bargain.',
#  'genres': ['Action', 'Drama', 'Western'],
#  'imdb': {'id': 58461, 'rating': 8.1, 'votes': 126585},
#  'languages': ['Italian', 'Spanish', 'English'],
#  'lastupdated': '2015-09-02 00:17:22.303000000',
#  'num_mflix_comments': 0,
#  'plot': 'A wandering gunfighter plays two rival families against each other '
#          'in a town torn apart by greed, pride, and revenge.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjA1MGVlMGItNzgxMC00OWY4LWI4YjEtNTNmYWIzMGUxOGQzXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1967, 1, 18, 0, 0),
#  'runtime': 99,
#  'title': 'A Fistful of Dollars',
#  'tomatoes': {'consensus': "With Akira Kurosawa's Yojimbo as his template, "
#                            "Sergio Leone's A Fistful of Dollars helped define "
#                            'a new era for the Western and usher in its most '
#                            'iconic star, Clint Eastwood.',
#               'critic': {'meter': 98, 'numReviews': 43, 'rating': 8.1},
#               'dvd': datetime.datetime(2001, 6, 19, 0, 0),
#               'fresh': 42,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 1, 55),
#               'production': 'MGM Home Entertainment',
#               'rotten': 1,
#               'viewer': {'meter': 91, 'numReviews': 85171, 'rating': 3.9}},
#  'type': 'movie',
#  'writers': ['Adriano Bolzoni (story)',
#              'Vèctor Andrès Catena (story)',
#              'Sergio Leone (story)',
#              'Vèctor Andrès Catena (screenplay)',
#              'Jaime Comas Gil (screenplay)',
#              'Sergio Leone (screenplay)'],
#  'year': 1964}
# {'_id': ObjectId('573a1396f29313caabce3dcf'),
#  'awards': {'nominations': 3,
#             'text': 'Nominated for 2 Oscars. Another 6 wins & 3 nominations.',
#             'wins': 8},
#  'cast': ['William Holden', 'Ernest Borgnine', 'Robert Ryan', "Edmond O'Brien"],
#  'countries': ['USA'],
#  'directors': ['Sam Peckinpah'],
#  'fullplot': "In the Wild Bunch the movie opens with a group of aging outlaw's "
#              'final score, a bank robbery. The event concludes with a violent '
#              'and overtly bloody shootout that would generally mark the finale '
#              'of a movie. This is correct in that it marks the finale of an '
#              'era, for the characters and the world they live in. They simply '
#              'can no longer keep up, the times are changing, technology '
#              "advancing, and they're style of life is getting left behind in "
#              'the dust that they spent so long galloping through. They abandon '
#              'their careers for the simpler life of retirement. They enjoy '
#              'this time, they live their fantasies. During this time the law '
#              'is always on their tracks, bounty hunters. The further into '
#              'their fantasy they get, the closer their demise seems to get. '
#              'When one of their own is captured they are faced with the choice '
#              'of escape or what is certainly a suicide mission to attempt and '
#              'free their fallen behind comrade. For them it is not a choice. '
#              'They all die in what can only be described as a nauseatingly '
#              'gore filled bloodbath of a battle. They might have succeeded in '
#              'removing themselves from the wild west however they could not be '
#              'separated what is inherently their nature. The west was only '
#              'wild because the wild bunch were present, they influenced their '
#              'surroundings, not the other way around. It is only after the '
#              'final shoot out that the bounty hunters catch up with them, now '
#              'only bullet riddled corpses. They never got caught, they could '
#              'never get caught because they were already trapped in their own '
#              'personalities. They turned themselves in to their instincts. The '
#              'vacation, the fantasy, was bound to end and they knew it.',
#  'genres': ['Action', 'Adventure', 'Western'],
#  'imdb': {'id': 65214, 'rating': 8.1, 'votes': 59133},
#  'languages': ['English', 'Spanish', 'German'],
#  'lastupdated': '2015-08-20 00:39:59.720000000',
#  'num_mflix_comments': 1,
#  'plot': 'An aging group of outlaws look for one last big score as the '
#          '"traditional" American West is disappearing around them.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGUyYTZmOWItMDJhMi00N2IxLWIyNDMtNjUxM2ZiYmU5YWU1XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1969, 6, 18, 0, 0),
#  'runtime': 145,
#  'title': 'The Wild Bunch',
#  'tomatoes': {'critic': {'meter': 98, 'numReviews': 48, 'rating': 8.8},
#               'dvd': datetime.datetime(1997, 8, 27, 0, 0),
#               'fresh': 47,
#               'lastUpdated': datetime.datetime(2015, 9, 16, 17, 32, 47),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 91, 'numReviews': 33369, 'rating': 4.1}},
#  'type': 'movie',
#  'writers': ['Walon Green (screenplay)',
#              'Sam Peckinpah (screenplay)',
#              'Walon Green (story)',
#              'Roy N. Sickner (story)'],
#  'year': 1969}
# {'_id': ObjectId('573a1396f29313caabce4122'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Amza Pellea', 'Ion Besoiu', 'Olga Tudorache', 'Irina Gardescu'],
#  'countries': ['Romania', 'France', 'Italy'],
#  'directors': ['Sergiu Nicolaescu'],
#  'fullplot': 'An epic fresco depicting the reign (1593-1601) of Mihai Pètrascu '
#              '(better known as "Mihai Viteazul" / "Michael the Brave"), the '
#              'famous prince who united the three provinces: Transalpine '
#              'Vallachia, Transylvania and Moldavia, into the country of '
#              'Romania, at the end of the 16th century (1599-1601) against the '
#              'opposition of the Ottoman and Austrian Empires, this movie '
#              'features large scale battle scenes mixed with political '
#              'intrigues, murderous treachery, and family drama.',
#  'genres': ['Action', 'Biography', 'Drama'],
#  'imdb': {'id': 66078, 'rating': 8.3, 'votes': 5354},
#  'languages': ['Romanian'],
#  'lastupdated': '2015-09-10 17:55:03.667000000',
#  'num_mflix_comments': 0,
#  'plot': 'At the end of the 16th century Wallachian ruler Prince Michael the '
#          'Brave overcame the adversity of the Ottoman and Austrian Empires to '
#          'unite Wallachia, Moldavia and Transylvania into one country.',
#  'runtime': 203,
#  'title': 'Michael the Brave',
#  'tomatoes': {'critic': {'meter': 89, 'numReviews': 9, 'rating': 6.6},
#               'dvd': datetime.datetime(2004, 4, 27, 0, 0),
#               'fresh': 8,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 19, 17, 38),
#               'production': 'Paramount Home Video',
#               'rotten': 1,
#               'viewer': {'meter': 64, 'numReviews': 1511, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Titus Popovici'],
#  'year': 1970}
# {'_id': ObjectId('573a1396f29313caabce5a56'),
#  'awards': {'nominations': 0, 'text': '7 wins.', 'wins': 7},
#  'cast': ['Shashi Kapoor', 'Amitabh Bachchan', 'Neetu Singh', 'Nirupa Roy'],
#  'countries': ['India'],
#  'directors': ['Yash Chopra'],
#  'fullplot': 'The movie tells the story of two brothers, Vijay and Ravi Verma, '
#              'who follow different career paths: Vijay is a smuggler and Ravi '
#              'the policeman who is asked to hunt Vijay down. Vijay Verma '
#              '(Amitabh Bachchan) and Ravi Verma (Shashi Kapoor) are the sons '
#              'of a trade unionist, Anand Verma(Satyen Kappu), who was defeated '
#              'and disgraced by the management of his firm using his family as '
#              'bait. Unable to bear the public disgrace father deserts the '
#              'family, and the sons are raised by their mother(Nirupa Roy)who '
#              'brings them to Bombay City, who suffers the trials and '
#              'tribulations of a poor single mother. Vijay Verma, the elder '
#              "brother, grows up with an acute awareness of his father's "
#              "humiliation and is victimized for his father's supposed "
#              'misdeeds. In the process of fighting for his rights Vijay, who '
#              'starts out as a boot polisher and becomes a dockyard worker in '
#              'his youth, becomes a smuggler and a leading figure of the '
#              'underworld.',
#  'genres': ['Action', 'Crime', 'Drama'],
#  'imdb': {'id': 72860, 'rating': 8.1, 'votes': 4753},
#  'languages': ['Hindi'],
#  'lastupdated': '2015-09-17 04:37:47.103000000',
#  'num_mflix_comments': 0,
#  'plot': 'As a youth, Vijay struggles as a dockworker. Eventually, he becomes '
#          'a leading figure of the underworld, while younger brother, Ravi, is '
#          'an educated, upright policeman. But in the end, it all comes down '
#          'to, who does mother love more?',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTU2NTYyOTA3NV5BMl5BanBnXkFtZTcwMDMyNjEzMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1979, 5, 1, 0, 0),
#  'runtime': 174,
#  'title': 'Deewaar',
#  'tomatoes': {'dvd': datetime.datetime(2004, 3, 30, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 15, 17, 6, 19),
#               'viewer': {'meter': 85, 'numReviews': 1174, 'rating': 4.0}},
#  'type': 'movie',
#  'writers': ['Javed Akhtar (dialogue)',
#              'Javed Akhtar (screenplay)',
#              'Javed Akhtar (story)',
#              'Salim Khan (dialogue)',
#              'Salim Khan (screenplay)',
#              'Salim Khan (story)'],
#  'year': 1975}
# {'_id': ObjectId('573a1397f29313caabce5d93'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Dharmendra', 'Sanjeev Kumar', 'Hema Malini', 'Amitabh Bachchan'],
#  'countries': ['India'],
#  'directors': ['Ramesh Sippy'],
#  'fullplot': 'Sholay means embers in Hindi. In this particular movie, a Police '
#              "Officer, who's family was killed by a bandit named Gabbar Singh, "
#              'decides to fight fire with fire and recruits two convicts, Jai '
#              'and Veeru to capture Gabbar. He approaches them in jail, puts '
#              'the proposal in front of them, and they agree to bring in Gabbar '
#              'Singh alive - for a hefty price. After their discharge from '
#              'jail, they travel by train to the village where the Police '
#              'Officer lives - now with only his widowed daughter-in-law. The '
#              'three band together to fight one of the most elusive and dreaded '
#              'bandits of all time. Will the two ex-cons be able to bring '
#              'Gabbar alive to the Police Officer?',
#  'genres': ['Action', 'Adventure', 'Comedy'],
#  'imdb': {'id': 73707, 'rating': 8.6, 'votes': 22725},
#  'languages': ['Hindi'],
#  'lastupdated': '2015-08-15 00:20:17.553000000',
#  'num_mflix_comments': 0,
#  'plot': 'After his family is murdered by a notorious and ruthless bandit, a '
#          'former police officer enlists the services of two outlaws to capture '
#          'him.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BOGZiM2IwODktNTdiMC00MGU1LWEyZTYtOTk4NTkwYmJkNmI1L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1975, 8, 15, 0, 0),
#  'runtime': 162,
#  'title': 'Sholay',
#  'type': 'movie',
#  'writers': ['Javed Akhtar', 'Salim Khan'],
#  'year': 1975}

# %% [markdown]
# ## 3. Advanced MongoDB Operations
# ### Aggregation Example: Average IMDb Rating by Genre

# %%
# Aggregation pipeline to calculate average IMDb rating by genre
aggregation_pipeline = [
    {"$unwind": "$genres"},  # Separate each movie's genres into individual documents
    {"$group": {"_id": "$genres", "avg_rating": {"$avg": "$imdb.rating"}}},
    {"$sort": {"avg_rating": -1}},
    {"$limit": 5}
]

# Execute the aggregation
aggregated_data = collection.aggregate(aggregation_pipeline)

# Print the results
for data in aggregated_data:
    pprint.pprint(data)

# %% [markdown]
# ### Indexing: Creating an Index

# %%
# Create an index on the "year" field to improve query performance for year-related searches
collection.create_index([("year", 1)])

# Show existing indexes
indexes = collection.index_information()
pprint.pprint(indexes)

# %% [markdown]
# ### Updating Documents

# %%
# Update a movie's IMDb rating (change the rating of a specific movie)
collection.update_one({"title": "The Godfather"}, {"$set": {"imdb.rating": 9.3}})

# %% [markdown]
# ### Deleting Documents

# %%
# Delete a movie based on a condition (delete movies that were released before 1950)
#collection.delete_many({"year": {"$lt": 1950}})

# %% [markdown]
# ## 4. Exercises for Hands-On Practice
# ### Exercise 1: Searching and Filtering
# **Task**: Find all movies where the genre is 'Comedy' and the IMDb rating is greater than 7.

# %%
# Your task: Write a query to find comedies with an IMDb rating greater than 7
comedies = collection.find({"genres": "Comedy", "imdb.rating": {"$gt": 7}}).limit(5)

# Print the first 5 results
for comedy in comedies:
    pprint.pprint(comedy)
# Out:
# {'_id': ObjectId('573a1390f29313caabcd4803'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Winsor McCay'],
#  'countries': ['USA'],
#  'directors': ['Winsor McCay', 'J. Stuart Blackton'],
#  'fullplot': 'Cartoonist Winsor McCay agrees to create a large set of drawings '
#              'that will be photographed and made into a motion picture. The '
#              'job requires plenty of drawing supplies, and the cartoonist must '
#              'also overcome some mishaps caused by an assistant. Finally, the '
#              'work is done, and everyone can see the resulting animated '
#              'picture.',
#  'genres': ['Animation', 'Short', 'Comedy'],
#  'imdb': {'id': 1737, 'rating': 7.3, 'votes': 1034},
#  'languages': ['English'],
#  'lastupdated': '2015-08-29 01:09:03.030000000',
#  'num_mflix_comments': 0,
#  'plot': 'Cartoon figures announce, via comic strip balloons, that they will '
#          'move - and move they do, in a wildly exaggerated style.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYzg2NjNhNTctMjUxMi00ZWU4LWI3ZjYtNTI0NTQxNThjZTk2XkEyXkFqcGdeQXVyNzg5OTk2OA@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1911, 4, 8, 0, 0),
#  'runtime': 7,
#  'title': 'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His '
#           'Moving Comics',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 20, 18, 51, 24),
#               'viewer': {'meter': 47, 'numReviews': 89, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Winsor McCay (comic strip "Little Nemo in Slumberland")',
#              'Winsor McCay (screenplay)'],
#  'year': 1911}
# {'_id': ObjectId('573a1390f29313caabcd50e5'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Winsor McCay', 'George McManus', 'Roy L. McCardell'],
#  'countries': ['USA'],
#  'directors': ['Winsor McCay'],
#  'fullplot': 'Winsor Z. McCay bets another cartoonist that he can animate a '
#              'dinosaur. So he draws a big friendly herbivore called Gertie. '
#              'Then he get into his own picture. Gertie walks through the '
#              'picture, eats a tree, meets her creator, and takes him carefully '
#              'on her back for a ride.',
#  'genres': ['Animation', 'Short', 'Comedy'],
#  'imdb': {'id': 4008, 'rating': 7.3, 'votes': 1837},
#  'languages': ['English'],
#  'lastupdated': '2015-08-18 01:03:15.313000000',
#  'num_mflix_comments': 0,
#  'plot': 'The cartoonist, Winsor McCay, brings the Dinosaurus back to life in '
#          'the figure of his latest creation, Gertie the Dinosaur.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQxNzI4ODQ3NF5BMl5BanBnXkFtZTgwNzY5NzMwMjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1914, 9, 15, 0, 0),
#  'runtime': 12,
#  'title': 'Gertie the Dinosaur',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 10, 19, 20, 3),
#               'viewer': {'numReviews': 29, 'rating': 3.7}},
#  'type': 'movie',
#  'writers': ['Winsor McCay'],
#  'year': 1914}
# {'_id': ObjectId('573a1391f29313caabcd6e2a'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Buster Keaton', 'Sybil Seely'],
#  'countries': ['USA'],
#  'directors': ['Edward F. Cline', 'Buster Keaton'],
#  'fullplot': 'Buster and Sybil exit a chapel as newlyweds. Among the gifts is '
#              "a portable house you easily put together in one week. It doesn't "
#              "help that Buster's rival for Sybil switches the numbers on the "
#              'crates containing the house parts.',
#  'genres': ['Short', 'Comedy'],
#  'imdb': {'id': 11541, 'rating': 8.3, 'votes': 3942},
#  'languages': ['English'],
#  'lastupdated': '2015-05-07 01:07:01.633000000',
#  'num_mflix_comments': 0,
#  'plot': 'A newly wedded couple attempt to build a house with a prefabricated '
#          "kit, unaware that a rival sabotaged the kit's component numbering.",
#  'rated': 'TV-G',
#  'released': datetime.datetime(1920, 9, 1, 0, 0),
#  'runtime': 25,
#  'title': 'One Week',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 18, 22, 19),
#               'viewer': {'meter': 91, 'numReviews': 752, 'rating': 4.3}},
#  'type': 'movie',
#  'year': 1920}
# {'_id': ObjectId('573a1391f29313caabcd71e3'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Lois Wilson', 'Milton Sills', 'Theodore Roberts', 'Helen Ferguson'],
#  'countries': ['USA'],
#  'directors': ['William C. de Mille'],
#  'fullplot': 'Wlliam deMille produced and directed Miss Lulu Bett, a film of '
#              'extraordinary conviction and insight. It was then often the '
#              'custom for unmarried women to lodge with family; thus we '
#              'discover Miss Lulu in a boring Midwestern town, an exploited '
#              'household drudge for her sister and her overbearing '
#              'brother-in-law. In the course of the story (based upon the '
#              'Pulitzer Prize play and novel by Zona Gale), Lulu evolves from '
#              'slavery into an attractive and self-assured woman, prepared to '
#              'make her own life. Revealed through wonderful performances and '
#              'clever use of props, the characters are extraordinarily solid '
#              'and involving.',
#  'genres': ['Comedy', 'Drama'],
#  'imdb': {'id': 12465, 'rating': 7.2, 'votes': 204},
#  'lastupdated': '2015-08-21 00:15:46.140000000',
#  'num_mflix_comments': 0,
#  'plot': 'Wlliam deMille produced and directed Miss Lulu Bett, a film of '
#          'extraordinary conviction and insight. It was then often the custom '
#          'for unmarried women to lodge with family; thus we discover ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY5MTY0MzY0Ml5BMl5BanBnXkFtZTgwNjE4NDAxMjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1921, 11, 1, 0, 0),
#  'runtime': 71,
#  'title': 'Miss Lulu Bett',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 5, 2, 19, 3, 48),
#               'viewer': {'numReviews': 2, 'rating': 2.5}},
#  'type': 'movie',
#  'writers': ['Clara Beranger (adaptation)', 'Zona Gale (novel)'],
#  'year': 1921}
# {'_id': ObjectId('573a1391f29313caabcd79e4'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Buster Keaton', 'Margaret Leahy', 'Wallace Beery', 'Joe Roberts'],
#  'countries': ['USA'],
#  'directors': ['Edward F. Cline', 'Buster Keaton'],
#  'fullplot': 'In his first independently produced feature film Buster tells of '
#              'love and romance through three historical ages: the Stone Age, '
#              'the Roman Age, and the Modern Age.',
#  'genres': ['Comedy'],
#  'imdb': {'id': 14538, 'rating': 7.2, 'votes': 2628},
#  'lastupdated': '2015-08-05 01:02:46.273000000',
#  'num_mflix_comments': 0,
#  'plot': 'The misadventures of Buster in three separate historical periods.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjI3OTEzODA4NF5BMl5BanBnXkFtZTgwODc0NDIwMjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1923, 9, 24, 0, 0),
#  'runtime': 63,
#  'title': 'Three Ages',
#  'tomatoes': {'critic': {'meter': 100, 'numReviews': 8, 'rating': 7.2},
#               'dvd': datetime.datetime(1999, 11, 23, 0, 0),
#               'fresh': 8,
#               'lastUpdated': datetime.datetime(2015, 8, 9, 18, 36),
#               'rotten': 0,
#               'viewer': {'meter': 77, 'numReviews': 1412, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Clyde Bruckman (story)',
#              'Joseph A. Mitchell (story)',
#              'Jean C. Havez (story)'],
#  'year': 1923}

# %% [markdown]
# ### Exercise 2: Aggregation Pipeline
# **Task**: Write an aggregation pipeline to find the top 5 directors by the average IMDb rating of their movies.

# %%
# Your task: Write an aggregation pipeline to calculate average IMDb rating by director
pipeline = [
    {"$group": {"_id": "$directors", "avg_rating": {"$avg": "$imdb.rating"}}},
    {"$sort": {"avg_rating": -1}},
    {"$limit": 5}
]

# Execute the pipeline and print results
avg_rating_by_director = collection.aggregate(pipeline)
for data in avg_rating_by_director:
    pprint.pprint(data)
# Out:
# {'_id': ['Sara Hirsh Bordo'], 'avg_rating': 9.4}
# {'_id': ['Kevin Derek'], 'avg_rating': 9.3}
# {'_id': ['Michael Benson'], 'avg_rating': 9.0}
# {'_id': ['Slobodan Sijan'], 'avg_rating': 8.95}
# {'_id': ['Sundar C.'], 'avg_rating': 8.9}

# %% [markdown]
# ### Exercise 3: Create an Index and Measure Performance
# **Task**: Create an index on the `imdb.rating` field. Measure performance before and after creating the index.

# %%
# Task: Create an index on imdb.rating and query before and after indexing

# Query without index
from time import time

start_time = time()
no_index_result = collection.find({"imdb.rating": {"$gt": 8}}).limit(5)
print("Time without index:", time() - start_time)

# Create an index
collection.create_index([("imdb.rating", 1)])

# Query with index
start_time = time()
with_index_result = collection.find({"imdb.rating": {"$gt": 8}}).limit(5)
print("Time with index:", time() - start_time)

# Print the results
for result in with_index_result:
    pprint.pprint(result)
# Out:
# Time without index: 0.0001518726348876953
# Time with index: 0.00015044212341308594
# {'_id': ObjectId('573a1391f29313caabcd72f0'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Richard Barthelmess',
#           'Gladys Hulette',
#           'Walter P. Lewis',
#           'Ernest Torrence'],
#  'countries': ['USA'],
#  'directors': ['Henry King'],
#  'fullplot': 'When three thuggish men are responsible for the death of his '
#              'father and the crippling of his brother, young David must choose '
#              'between supporting his family or risking his life and exacting '
#              'vengeance.',
#  'genres': ['Drama'],
#  'imdb': {'id': 12763, 'rating': 8.1, 'votes': 1455},
#  'lastupdated': '2015-08-23 01:12:08.943000000',
#  'num_mflix_comments': 0,
#  'plot': 'When three thuggish men are responsible for the death of his father '
#          'and the crippling of his brother, young David must choose between '
#          'supporting his family or risking his life and exacting vengeance.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjIwMzA3MDAyNl5BMl5BanBnXkFtZTgwNzMyNTE1MjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1921, 12, 31, 0, 0),
#  'runtime': 99,
#  'title': "Tol'able David",
#  'tomatoes': {'dvd': datetime.datetime(1999, 3, 23, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 26, 18, 24, 46),
#               'production': 'Universum Film A.G. (UFA)',
#               'viewer': {'meter': 70, 'numReviews': 249, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Joseph Hergesheimer (novel)', 'Edmund Goulding', 'Henry King'],
#  'year': 1921}
# {'_id': ObjectId('573a1391f29313caabcd82da'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Colleen Moore', 'Lloyd Hughes', 'Vera Lewis', 'Doris Baker'],
#  'countries': ['USA'],
#  'directors': ['Alfred E. Green'],
#  'fullplot': 'Poor Ella Cinders is much abused by her evil step-mother and '
#              'step-sisters. When she wins a local beauty contest she jumps at '
#              'the chance to get out of her dead-end life and go to Hollywood, '
#              'where she is promised a job in the movies. When she arrives in '
#              'Hollywood, she discoves that the contest was a scam and the job '
#              'non-existant. But through pluck, luck, and talent, she makes it '
#              'in the movies anyway, and finds true love.',
#  'genres': ['Comedy', 'Romance'],
#  'imdb': {'id': 16822, 'rating': 8.1, 'votes': 694},
#  'languages': ['English'],
#  'lastupdated': '2015-09-02 00:38:57.710000000',
#  'num_mflix_comments': 1,
#  'plot': 'Poor Ella Cinders is much abused by her evil step-mother and '
#          'step-sisters. When she wins a local beauty contest she jumps at the '
#          'chance to get out of her dead-end life and go to Hollywood, ...',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1926, 6, 6, 0, 0),
#  'runtime': 75,
#  'title': 'Ella Cinders',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 20, 18, 5, 14),
#               'production': 'First National Pictures Inc.',
#               'viewer': {'numReviews': 7, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Mervyn LeRoy (story)',
#              'Frank Griffin (story)',
#              'Mervyn LeRoy (scenario)',
#              'Frank Griffin (scenario)',
#              'George Marion Jr. (titles)',
#              'William M. Conselman (comic strip)',
#              'Charles Plumb (comic strip)'],
#  'year': 1926}
# {'_id': ObjectId('573a1392f29313caabcd9bf8'),
#  'awards': {'nominations': 0, 'text': 'Won 1 Oscar. Another 1 win.', 'wins': 2},
#  'cast': ['Stan Laurel', 'Oliver Hardy'],
#  'countries': ['USA'],
#  'directors': ['James Parrott'],
#  'fullplot': 'The Laurel & Hardy Moving Co. have a challenging job on their '
#              'hands (and backs): hauling a player piano up a monumental flight '
#              "of stairs to Prof. von Schwarzenhoffen's house. Their task is "
#              'complicated by a sassy nursemaid and, unbeknownst to them, the '
#              'impatient Prof. von Schwarzenhoffen himself. But the biggest '
#              'problem is the force of gravity, which repeatedly pulls the '
#              'piano back down to the bottom of the stairs. Finally, the irate '
#              'Professor explodes in fury to discover the "mechanical '
#              'blunderbuss" in his home, not knowing it was a surprise birthday '
#              'present from his wife.',
#  'genres': ['Comedy', 'Short'],
#  'imdb': {'id': 23251, 'rating': 8.1, 'votes': 4449},
#  'languages': ['English'],
#  'lastupdated': '2015-08-18 00:27:13.017000000',
#  'num_mflix_comments': 1,
#  'plot': 'Like the legendary Sisyphus, deliverymen Laurel and Hardy struggle '
#          'to push a large crated piano up a seemingly insurmountable flight of '
#          'stairs.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjRhMjBiMTAtYmEzOC00ZDg1LWJmNzQtMDA2ZjlkMzk0OWM3XkEyXkFqcGdeQXVyMjExNjgyMTc@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1932, 4, 16, 0, 0),
#  'runtime': 29,
#  'title': 'The Music Box',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 10, 19, 12, 37),
#               'viewer': {'meter': 92, 'numReviews': 2150, 'rating': 4.2}},
#  'type': 'movie',
#  'writers': ['H.M. Walker (dialogue)'],
#  'year': 1932}
# {'_id': ObjectId('573a1392f29313caabcd9f09'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Marion Davies', 'Bing Crosby', "Fifi D'Orsay", 'Stuart Erwin'],
#  'countries': ['USA'],
#  'directors': ['Raoul Walsh'],
#  'fullplot': "Sylvia is the French teacher at Briarcroft's School for Girls, "
#              'but she wants to find romance. When she hears Bill on the radio, '
#              'she decides to leave and thank him. But he is on his way to '
#              'Hollywood with Lili to make a movie. When Sylvia gets to '
#              'Hollywood, she finds that seeing Bill again is almost '
#              'impossible, but she gets a job in the chorus. Then when Lili '
#              'quits the picture, Sylvia is tapped to play her character. But '
#              'the part she wants is with Bill, a part that Lili seems to have.',
#  'genres': ['Musical', 'Romance'],
#  'imdb': {'id': 24067, 'rating': 8.1, 'votes': 1330},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-09-15 03:21:37.663000000',
#  'num_mflix_comments': 1,
#  'plot': "Sylvia is the French teacher at Briarcroft's School for Girls, but "
#          'she wants to find romance. When she hears Bill on the radio, she '
#          'decides to leave and thank him. But he is on his way to ...',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1933, 12, 22, 0, 0),
#  'runtime': 78,
#  'title': 'Going Hollywood',
#  'tomatoes': {'dvd': datetime.datetime(1993, 5, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 23, 18, 35, 1),
#               'viewer': {'meter': 75, 'numReviews': 15, 'rating': 3.5}},
#  'type': 'movie',
#  'writers': ['Donald Ogden Stewart (screen play)'],
#  'year': 1933}
# {'_id': ObjectId('573a1392f29313caabcda998'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Groucho Marx', 'Chico Marx', 'Harpo Marx', 'Kitty Carlisle'],
#  'countries': ['USA'],
#  'directors': ['Sam Wood', 'Edmund Goulding'],
#  'fullplot': 'The Marx Brothers take on high society. Two lovers who are both '
#              "in opera are prevented from being together by the man's lack of "
#              'acceptance as an operatic tenor. Pulling several typical Marx '
#              "Brothers' stunts, they arrange for the normal tenor to be absent "
#              'so that the young lover can get his chance.',
#  'genres': ['Comedy', 'Music', 'Musical'],
#  'imdb': {'id': 26778, 'rating': 8.1, 'votes': 23598},
#  'languages': ['English', 'Italian'],
#  'lastupdated': '2015-09-17 02:11:55.840000000',
#  'num_mflix_comments': 1,
#  'plot': 'A sly business manager and two wacky friends of two opera singers '
#          'help them achieve success while humiliating their stuffy and '
#          'snobbish enemies.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYTJmNmQxNGItNDNlMC00MDU3LWFhNzMtZDQ2NDY0ZTVkNjE3XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1935, 11, 15, 0, 0),
#  'runtime': 96,
#  'title': 'A Night at the Opera',
#  'tomatoes': {'critic': {'meter': 97, 'numReviews': 37, 'rating': 8.6},
#               'dvd': datetime.datetime(2006, 1, 13, 0, 0),
#               'fresh': 36,
#               'lastUpdated': datetime.datetime(2015, 8, 25, 19, 23, 19),
#               'production': 'MGM',
#               'rotten': 1,
#               'viewer': {'meter': 91, 'numReviews': 20066, 'rating': 4.1}},
#  'type': 'movie',
#  'writers': ['George S. Kaufman (screen play)',
#              'Morrie Ryskind (screen play)',
#              'James Kevin McGuinness (from a story by)'],
#  'year': 1935}

# %% [markdown]
# ## **Homework**

# %%
#Exercise 1: Basic Searching and Filtering

#Write a query to find the first movie that has the genre "Action".
first_action_movie = collection.find_one({"genres": "Action"})
pprint.pprint(first_action_movie)

#Write a query to find all movies released after the year 2000 (Return the first 5 results).
movies_after_2000 = collection.find({"year": {"$gt": 2000}}).limit(5)
for movie in movies_after_2000:
    pprint.pprint(movie)

#Write a query to find all movies where the IMDb rating is greater than 8.5 (Return the
#first 5 results).
high_rated_movies = collection.find({"imdb.rating": {"$gt": 8.5}}).limit(5)
for movie in high_rated_movies:
    pprint.pprint(movie)

#Write a query to find all movies where the genre contains both "Action" and "Adventure".
action_adventure_movies = collection.find({ "genres": { "$all": ["Action", "Adventure"] } }).limit(5)
for movie in action_adventure_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1394f29313caabcde741'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Margaret Lockwood', 'Dane Clark', 'Marius Goring', 'Naunton Wayne'],
#  'countries': ['UK'],
#  'directors': ['Roy Ward Baker'],
#  'fullplot': 'When British Intelligence discovers that an Iron Curtian country '
#              'is developing insects as weapons they persuade eminent '
#              'entomologist Frances Gray to get into the country to collect '
#              'some specimens. On arrival her cover is almost immediately blown '
#              'and her contact murdered. The future looks grim for her and also '
#              'perhaps for the world.',
#  'genres': ['Action', 'Thriller'],
#  'imdb': {'id': 42553, 'rating': 5.8, 'votes': 321},
#  'languages': ['English'],
#  'lastupdated': '2015-09-17 04:50:07.010000000',
#  'num_mflix_comments': 0,
#  'plot': 'A British lady entomologist travels to a Balkan country to look into '
#          'germ warfare trials using various bugs as carriers.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ0ODYwNTYzOV5BMl5BanBnXkFtZTgwMDM2OTgwMzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1951, 10, 12, 0, 0),
#  'runtime': 90,
#  'title': 'Highly Dangerous',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 5, 26, 18, 22, 40),
#               'viewer': {'numReviews': 24, 'rating': 2.9}},
#  'type': 'movie',
#  'writers': ['Eric Ambler'],
#  'year': 1950}
# {'_id': ObjectId('573a1393f29313caabcdcb42'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 1 Oscar. Another 1 win & 4 nominations.',
#             'wins': 2},
#  'cast': ['Meg Ryan', 'Hugh Jackman', 'Liev Schreiber', 'Breckin Meyer'],
#  'countries': ['USA'],
#  'directors': ['James Mangold'],
#  'fullplot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#              'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#              'space near the Brooklyn Bridge where there is a gap in time. He '
#              'goes back to the 19th Century and takes pictures of the place. '
#              "Leopold -- a man living in the 1870s -- is puzzled by Stuart's "
#              'tiny camera, follows him back through the gap, and they both '
#              'ended up in the present day. Leopold is clueless about his new '
#              'surroundings. He gets help and insight from Charlie who thinks '
#              'that Leopold is an actor who is always in character. Leopold is '
#              'a highly intelligent man and tries his best to learn and even '
#              'improve the modern conveniences that he encounters.',
#  'genres': ['Comedy', 'Fantasy', 'Romance'],
#  'imdb': {'id': 35423, 'rating': 6.3, 'votes': 59951},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-08-31 00:19:09.717000000',
#  'metacritic': 44,
#  'num_mflix_comments': 0,
#  'plot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#          'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#          'space near the Brooklyn Bridge where there is a gap in time....',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNmNlN2VlOTctYTdhMS00NzUxLTg0ZGMtYWE2ZTJmMThlMTk2XkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 12, 25, 0, 0),
#  'runtime': 118,
#  'title': 'Kate & Leopold',
#  'tomatoes': {'boxOffice': '$47.1M',
#               'consensus': 'Though Jackman charms, Kate and Leopold is bland '
#                            'and predictable, and the time travel scenario '
#                            'lacks inner logic.',
#               'critic': {'meter': 50, 'numReviews': 126, 'rating': 5.3},
#               'dvd': datetime.datetime(2002, 6, 11, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 8, 22, 18, 53, 25),
#               'production': 'Miramax Films',
#               'rotten': 63,
#               'viewer': {'meter': 62, 'numReviews': 189426, 'rating': 3.0},
#               'website': 'http://www.kateandleopold-themovie.com'},
#  'type': 'movie',
#  'writers': ['Steven Rogers (story)',
#              'James Mangold (screenplay)',
#              'Steven Rogers (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a1398f29313caabceb1fe'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Crispin Glover', 'Vanessa Redgrave', 'John Hurt', 'Margot Kidder'],
#  'countries': ['USA', 'Poland', 'Russia'],
#  'directors': ['Menahem Golan'],
#  'fullplot': "A modern day adaptation of Dostoyevsky's classic novel about a "
#              'young student who is forever haunted by the murder he has '
#              'committed.',
#  'genres': ['Drama'],
#  'imdb': {'id': 96056, 'rating': 6.4, 'votes': 463},
#  'languages': ['English', 'Polish'],
#  'lastupdated': '2015-08-13 00:34:02.303000000',
#  'num_mflix_comments': 0,
#  'plot': "A modern day adaptation of Dostoyevsky's classic novel about a young "
#          'student who is forever haunted by the murder he has committed.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTI3MDQ2MzEyOV5BMl5BanBnXkFtZTcwNzEwODUzMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2002, 6, 1, 0, 0),
#  'runtime': 126,
#  'title': 'Crime and Punishment',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 22, 18, 45, 10),
#               'viewer': {'numReviews': 0, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Fyodor Dostoevsky (novel)',
#              'Menahem Golan (adaptation)',
#              'Menahem Golan (screenplay)'],
#  'year': 2002}
# {'_id': ObjectId('573a139af29313caabcf0809'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Marcelo Games', 'Marc Pitman', 'Leslie Orr', 'Maureen Allisse'],
#  'countries': ['USA'],
#  'directors': ['Jim Van Bebber'],
#  'fullplot': 'If you think you know the story of the Manson Family, you are '
#              'dead wrong. On a ranch outside of Los Angeles, the dream of the '
#              '"Love Generation" is transforming into something evil. What was '
#              'once an oasis of free love and acid trips has become ground zero '
#              "for a madman's paranoid visions. An average group of kids, the "
#              '"Family," become engulfed in a delusional world where torment '
#              'and slaughter are considered the path to righteousness.Director '
#              'Jim VanBebber (Deadbeat at Dawn) delivers a dizzying, rapid-fire '
#              'vision of the sex and violence that unifies the misguided group, '
#              'a group hell-bent on executing the brutal vision of its leader, '
#              "Charles Manson. You've seen the story through the eyes of the "
#              'law. Now witness it through the eyes of THE MANSOSN FAMILY.',
#  'genres': ['Crime', 'Drama', 'History'],
#  'imdb': {'id': 118840, 'rating': 5.5, 'votes': 2565},
#  'languages': ['English'],
#  'lastupdated': '2015-09-03 00:41:23.867000000',
#  'metacritic': 56,
#  'num_mflix_comments': 0,
#  'plot': 'If you think you know the story of the Manson Family, you are dead '
#          'wrong. On a ranch outside of Los Angeles, the dream of the "Love '
#          'Generation" is transforming into something evil. What was...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTk1NDIzMjY3M15BMl5BanBnXkFtZTcwODE2ODYyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2004, 7, 23, 0, 0),
#  'runtime': 95,
#  'title': 'The Manson Family',
#  'tomatoes': {'critic': {'meter': 68, 'numReviews': 31, 'rating': 6.0},
#               'dvd': datetime.datetime(2005, 4, 26, 0, 0),
#               'fresh': 21,
#               'lastUpdated': datetime.datetime(2015, 7, 20, 18, 38, 35),
#               'production': 'Blue Underground',
#               'rotten': 10,
#               'viewer': {'meter': 48, 'numReviews': 7479, 'rating': 3.0},
#               'website': 'http://www2.themansonfamilymovie.com/'},
#  'type': 'movie',
#  'writers': ['Jim Van Bebber'],
#  'year': 2003}
# {'_id': ObjectId('573a139af29313caabcf0718'),
#  'awards': {'nominations': 8, 'text': '1 win & 8 nominations.', 'wins': 1},
#  'cast': ['Mariah Carey', 'Max Beesley', 'Da Brat', 'Tia Texada'],
#  'countries': ['USA'],
#  'directors': ['Vondie Curtis-Hall'],
#  'fullplot': 'Billie Frank is a shy, young multiracial girl who is sent away '
#              'by her alcoholic mother at a very early age. At an orphanage, '
#              'she befriends Louise and Roxanne. Flash forward to 1983. Billie '
#              'and her friends are spotted by a record producer, Timothy '
#              'Walker, who wants them to sing backup for his latest pop-music '
#              "discovery. But when super DJ Julian Dice hears Billie's "
#              'incredible voice, he makes a shady deal with Timothy to get her '
#              'out of that dead-end situation. Soon, Billie and Dice are making '
#              'hits inside the studio, and falling in love outside of it. '
#              'Eventually, the pressure of her newfound celebrity puts too '
#              'heavy a strain on Billie, forcing her to decide what it is she '
#              'really wants from Dice, and what she wants for herself.',
#  'genres': ['Drama', 'Music', 'Romance'],
#  'imdb': {'id': 118589, 'rating': 2.1, 'votes': 18840},
#  'languages': ['English'],
#  'lastupdated': '2015-08-21 00:47:31.610000000',
#  'metacritic': 14,
#  'num_mflix_comments': 0,
#  'plot': 'A young singer dates a disc jockey who helps her get into the music '
#          'business, but their relationship become complicated as she ascends '
#          'to super stardom.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMGJkN2IxNTYtZDE1OS00MWJhLWFhNzItNTZkMjM4OGUzMTE2L2ltYWdlXkEyXkFqcGdeQXVyNTg3MTc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 9, 21, 0, 0),
#  'runtime': 104,
#  'title': 'Glitter',
#  'tomatoes': {'boxOffice': '$3.9M',
#               'consensus': 'Glitter is a hodgepodge of movie cliches and bad '
#                            "acting that's sure to generate unintentional "
#                            'laughs. Unfortunately, the movie is not bad enough '
#                            'to be good.',
#               'critic': {'meter': 7, 'numReviews': 87, 'rating': 2.8},
#               'dvd': datetime.datetime(2002, 1, 15, 0, 0),
#               'fresh': 6,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 18, 37, 3),
#               'production': '20th Century Fox',
#               'rotten': 81,
#               'viewer': {'meter': 45, 'numReviews': 44284, 'rating': 2.1},
#               'website': 'http://216.133.243.94'},
#  'type': 'movie',
#  'writers': ['Cheryl L. West (story)', 'Kate Lanier (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a139af29313caabcf0869'),
#  'awards': {'nominations': 3, 'text': '1 win & 3 nominations.', 'wins': 1},
#  'cast': ['Javier Bardem',
#           'Juan Diego Botto',
#           'Laura Morante',
#           'Elvira Mènguez'],
#  'countries': ['Spain', 'USA'],
#  'directors': ['John Malkovich'],
#  'fullplot': 'The story of Detective Agustin Rejas, a man clinging to the hope '
#              'of an impossible love in an impossible world. Tracking Ezequiel, '
#              'a delusional anarchist who incites the downtrodden masses to '
#              'join in his brutal revolution against the fascist government in '
#              'their unnamed Latin American country, Rejas finds solace in his '
#              'sense of self-respect and the joy that his daughter and wife '
#              "bring him. Then he meets Yolanda--his daughter's soulfully "
#              'beautiful ballet teacher--a woman who sparks his long-forgotten '
#              'passions and represents all that is good and all that is corrupt '
#              'in their troubled country. But she, who appears to be a shelter '
#              "from the storm, may in actuality be the storm's eye. Ultimately, "
#              'as the revolution intensifies and the net closes around hunter '
#              "and hunted alike, the dancer's truth will prove as elusive as "
#              "the revolutionary's cause and the detective's peace.",
#  'genres': ['Drama', 'Thriller', 'Crime'],
#  'imdb': {'id': 118926, 'rating': 7.0, 'votes': 5359},
#  'languages': ['English', 'Quechua', 'Spanish'],
#  'lastupdated': '2015-09-07 01:12:12.077000000',
#  'metacritic': 64,
#  'num_mflix_comments': 0,
#  'plot': 'A police detective in a South American country is dedicated to '
#          'hunting down a revolutionary guerilla leader.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BODE2ODA5OTE1OV5BMl5BanBnXkFtZTYwNzk1MTc2._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2003, 5, 23, 0, 0),
#  'runtime': 132,
#  'title': 'The Dancer Upstairs',
#  'tomatoes': {'boxOffice': '$2.3M',
#               'consensus': 'Javier Bardem is compelling in the lead role as a '
#                            'police detective in search of a violent, '
#                            'mysterious politcal radical, and as a director, '
#                            'John Malkovich proves adept at crafting a '
#                            'suspenseful mood.',
#               'critic': {'meter': 64, 'numReviews': 114, 'rating': 6.4},
#               'dvd': datetime.datetime(2003, 9, 23, 0, 0),
#               'fresh': 73,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 10, 37, 43),
#               'production': 'Fox Searchlight Pictures',
#               'rotten': 41,
#               'viewer': {'meter': 77, 'numReviews': 4793, 'rating': 3.6},
#               'website': 'http://www.foxsearchlight.com/thedancerupstairs/'},
#  'type': 'movie',
#  'writers': ['Nicholas Shakespeare (novel)',
#              'Nicholas Shakespeare (screenplay)'],
#  'year': 2002}
# {'_id': ObjectId('573a1394f29313caabcdfa00'),
#  'awards': {'nominations': 7,
#             'text': 'Nominated for 4 Oscars. Another 7 wins & 7 nominations.',
#             'wins': 11},
#  'cast': ['James Stewart', 'Grace Kelly', 'Wendell Corey', 'Thelma Ritter'],
#  'countries': ['USA'],
#  'directors': ['Alfred Hitchcock'],
#  'fullplot': 'Professional photographer L.B. "Jeff" Jeffries breaks his leg '
#              'while getting an action shot at an auto race. Confined to his '
#              'New York apartment, he spends his time looking out of the rear '
#              'window observing the neighbors. He begins to suspect that a man '
#              'across the courtyard may have murdered his wife. Jeff enlists '
#              'the help of his high society fashion-consultant girlfriend Lisa '
#              'Freemont and his visiting nurse Stella to investigate.',
#  'genres': ['Mystery', 'Thriller'],
#  'imdb': {'id': 47396, 'rating': 8.6, 'votes': 283273},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:31:57.327000000',
#  'num_mflix_comments': 1,
#  'plot': 'A wheelchair bound photographer spies on his neighbours from his '
#          'apartment window and becomes convinced one of them has committed '
#          'murder.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGUxYWM3M2MtMGM3Mi00ZmRiLWE0NGQtZjE5ODI2OTJhNTU0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'runtime': 112,
#  'title': 'Rear Window',
#  'tomatoes': {'consensus': 'Hitchcock exerted full potential of suspense in '
#                            'this masterpiece.',
#               'critic': {'meter': 100, 'numReviews': 63, 'rating': 8.9},
#               'dvd': datetime.datetime(2001, 3, 6, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 7, 38),
#               'production': 'Paramount Pictures',
#               'rotten': 0,
#               'viewer': {'meter': 95, 'numReviews': 147500, 'rating': 4.2}},
#  'type': 'movie',
#  'writers': ['John Michael Hayes (screenplay)',
#              'Cornell Woolrich (based on the short story by)'],
#  'year': 1954}
# {'_id': ObjectId('573a1395f29313caabce144b'),
#  'awards': {'nominations': 5,
#             'text': 'Nominated for 4 Oscars. Another 7 wins & 5 nominations.',
#             'wins': 11},
#  'cast': ['Anthony Perkins', 'Vera Miles', 'John Gavin', 'Janet Leigh'],
#  'countries': ['USA'],
#  'directors': ['Alfred Hitchcock'],
#  'fullplot': 'Phoenix officeworker Marion Crane is fed up with the way life '
#              'has treated her. She has to meet her lover Sam in lunch breaks '
#              'and they cannot get married because Sam has to give most of his '
#              'money away in alimony. One Friday Marion is trusted to bank '
#              '$40,000 by her employer. Seeing the opportunity to take the '
#              'money and start a new life, Marion leaves town and heads towards '
#              "Sam's California store. Tired after the long drive and caught in "
#              'a storm, she gets off the main highway and pulls into The Bates '
#              'Motel. The motel is managed by a quiet young man called Norman '
#              'who seems to be dominated by his mother.',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 54215, 'rating': 8.6, 'votes': 376318},
#  'languages': ['English'],
#  'lastupdated': '2015-09-04 00:05:08.977000000',
#  'num_mflix_comments': 0,
#  'plot': "A Phoenix secretary steals $40,000 from her employer's client, goes "
#          'on the run and checks into a remote motel run by a young man under '
#          'the domination of his mother.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNTQwNDM1YzItNDAxZC00NWY2LTk0M2UtNDIwNWI5OGUyNWUxXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1960, 9, 8, 0, 0),
#  'runtime': 109,
#  'title': 'Psycho',
#  'tomatoes': {'consensus': 'Infamous for its shower scene, but immortal for '
#                            'its contribution to the horror genre. Because '
#                            'Psycho was filmed with tact, grace, and art, '
#                            "Hitchcock didn't just create modern horror, he "
#                            'validated it.',
#               'critic': {'meter': 96, 'numReviews': 84, 'rating': 9.2},
#               'dvd': datetime.datetime(2001, 3, 6, 0, 0),
#               'fresh': 81,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 44, 21),
#               'production': 'Paramount Pictures',
#               'rotten': 3,
#               'viewer': {'meter': 94, 'numReviews': 236029, 'rating': 3.9}},
#  'type': 'movie',
#  'writers': ['Joseph Stefano (screenplay)', 'Robert Bloch (novel)'],
#  'year': 1960}
# {'_id': ObjectId('573a1396f29313caabce39e5'),
#  'awards': {'nominations': 4, 'text': '5 wins & 4 nominations.', 'wins': 5},
#  'cast': ['Claudia Cardinale',
#           'Henry Fonda',
#           'Jason Robards',
#           'Charles Bronson'],
#  'countries': ['Italy', 'USA', 'Spain'],
#  'directors': ['Sergio Leone'],
#  'fullplot': 'Story of a young woman, Mrs. McBain, who moves from New Orleans '
#              'to frontier Utah, on the very edge of the American West. She '
#              'arrives to find her new husband and family slaughtered, but by '
#              'whom? The prime suspect, coffee-lover Cheyenne, befriends her '
#              'and offers to go after the real killer, assassin gang leader '
#              'Frank, in her honor. He is accompanied by Harmonica, a man '
#              'already on a quest to get even.',
#  'genres': ['Western'],
#  'imdb': {'id': 64116, 'rating': 8.6, 'votes': 195109},
#  'languages': ['English', 'Spanish', 'Italian'],
#  'lastupdated': '2015-09-14 00:00:06.893000000',
#  'metacritic': 80,
#  'num_mflix_comments': 1,
#  'plot': 'Epic story of a mysterious stranger with a harmonica who joins '
#          'forces with a notorious desperado to protect a beautiful widow from '
#          'a ruthless assassin working for the railroad.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZGI5MjBmYzYtMzJhZi00NGI1LTk3MzItYjBjMzcxM2U3MDdiXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(1968, 12, 21, 0, 0),
#  'runtime': 175,
#  'title': 'Once Upon a Time in the West',
#  'tomatoes': {'consensus': 'A landmark Sergio Leone spaghetti western '
#                            'masterpiece featuring a classic Morricone score.',
#               'critic': {'meter': 98, 'numReviews': 54, 'rating': 9.0},
#               'dvd': datetime.datetime(2003, 11, 18, 0, 0),
#               'fresh': 53,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 53, 4),
#               'production': 'Paramount Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 95, 'numReviews': 63662, 'rating': 4.3}},
#  'type': 'movie',
#  'writers': ['Sergio Donati (screenplay)',
#              'Sergio Leone (screenplay)',
#              'Dario Argento (from a story by)',
#              'Bernardo Bertolucci (from a story by)',
#              'Sergio Leone (from a story by)'],
#  'year': 1968}
# {'_id': ObjectId('573a1396f29313caabce4a9a'),
#  'awards': {'nominations': 19,
#             'text': 'Won 3 Oscars. Another 30 wins & 19 nominations.',
#             'wins': 33},
#  'cast': ['Marlon Brando', 'Al Pacino', 'James Caan', 'Richard S. Castellano'],
#  'countries': ['USA'],
#  'directors': ['Francis Ford Coppola'],
#  'fullplot': 'When the aging head of a famous crime family decides to transfer '
#              'his position to one of his subalterns, a series of unfortunate '
#              'events start happening to the family, and a war begins between '
#              'all the well-known families leading to insolence, deportation, '
#              'murder and revenge, and ends with the favorable successor being '
#              'finally chosen.',
#  'genres': ['Crime', 'Drama'],
#  'imdb': {'id': 68646, 'rating': 9.5, 'votes': 1038358},
#  'languages': ['English', 'Italian', 'Latin'],
#  'lastupdated': '2015-09-02 00:08:23.680000000',
#  'metacritic': 100,
#  'num_mflix_comments': 131,
#  'plot': 'The aging patriarch of an organized crime dynasty transfers control '
#          'of his clandestine empire to his reluctant son.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1972, 3, 24, 0, 0),
#  'runtime': 175,
#  'title': 'The Godfather',
#  'tomatoes': {'consensus': "One of Hollywood's greatest critical and "
#                            'commercial successes, The Godfather gets '
#                            'everything right; not only did the movie transcend '
#                            'expectations, it established new benchmarks for '
#                            'American cinema.',
#               'critic': {'meter': 99, 'numReviews': 84, 'rating': 9.2},
#               'dvd': datetime.datetime(2001, 10, 9, 0, 0),
#               'fresh': 83,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 15, 13),
#               'production': 'Paramount Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 98, 'numReviews': 725773, 'rating': 4.4},
#               'website': 'http://www.thegodfather.com'},
#  'type': 'movie',
#  'writers': ['Mario Puzo (screenplay)',
#              'Francis Ford Coppola (screenplay)',
#              'Mario Puzo (novel)'],
#  'year': 1972}
# {'_id': ObjectId('573a1396f29313caabce557f'),
#  'awards': {'nominations': 16,
#             'text': 'Won 6 Oscars. Another 13 wins & 16 nominations.',
#             'wins': 19},
#  'cast': ['Al Pacino', 'Robert Duvall', 'Diane Keaton', 'Robert De Niro'],
#  'countries': ['USA'],
#  'directors': ['Francis Ford Coppola'],
#  'fullplot': 'The continuing saga of the Corleone crime family tells the story '
#              'of a young Vito Corleone growing up in Sicily and in 1910s New '
#              'York; and follows Michael Corleone in the 1950s as he attempts '
#              'to expand the family business into Las Vegas, Hollywood and '
#              'Cuba.',
#  'genres': ['Crime', 'Drama'],
#  'imdb': {'id': 71562, 'rating': 9.1, 'votes': 700857},
#  'languages': ['English', 'Italian', 'Spanish', 'Latin', 'Sicilian'],
#  'lastupdated': '2015-09-02 00:15:27.537000000',
#  'metacritic': 80,
#  'num_mflix_comments': 0,
#  'plot': 'The early life and career of Vito Corleone in 1920s New York is '
#          'portrayed while his son, Michael, expands and tightens his grip on '
#          'his crime syndicate stretching from Lake Tahoe, Nevada to '
#          'pre-revolution 1958 Cuba.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1974, 12, 20, 0, 0),
#  'runtime': 200,
#  'title': 'The Godfather: Part II',
#  'tomatoes': {'consensus': 'Drawing on strong performances by Al Pacino and '
#                            "Robert De Niro, Francis Ford Coppola's "
#                            "continuation of Mario Puzo's Mafia saga set new "
#                            'standards for sequels that have yet to be matched '
#                            'or broken.',
#               'critic': {'meter': 97, 'numReviews': 72, 'rating': 9.5},
#               'dvd': datetime.datetime(2005, 5, 24, 0, 0),
#               'fresh': 70,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 0, 43),
#               'production': 'Paramount Pictures',
#               'rotten': 2,
#               'viewer': {'meter': 97, 'numReviews': 407106, 'rating': 4.3},
#               'website': 'http://www.thegodfather.com/'},
#  'type': 'movie',
#  'writers': ['Francis Ford Coppola (screenplay)',
#              'Mario Puzo (screenplay)',
#              'Mario Puzo (based on the novel "The Godfather" by)'],
#  'year': 1974}
# {'_id': ObjectId('573a1394f29313caabcde77d'),
#  'awards': {'nominations': 1,
#             'text': 'Won 2 Oscars. Another 2 wins & 1 nomination.',
#             'wins': 4},
#  'cast': ['Deborah Kerr', 'Stewart Granger', 'Richard Carlson', 'Hugo Haas'],
#  'countries': ['USA'],
#  'directors': ['Compton Bennett', 'Andrew Marton'],
#  'fullplot': 'Guide Allan Quatermain helps a young lady (Beth) find her lost '
#              "husband somewhere in Africa. It's a spectacular adventure story "
#              'with romance, because while they fight with wild animals and '
#              'cannibals, they fall in love. Will they find the lost husband '
#              'and finish the nice connection?',
#  'genres': ['Adventure', 'Romance', 'Action'],
#  'imdb': {'id': 42646, 'rating': 6.9, 'votes': 4128},
#  'languages': ['English'],
#  'lastupdated': '2015-08-06 00:32:20.070000000',
#  'num_mflix_comments': 1,
#  'plot': 'Adventurer Allan Quartermain leads an expedition into uncharted '
#          'African territory in an attempt to locate an explorer who went '
#          'missing during his search for the fabled diamond mines of King '
#          'Solomon.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjZlOWFjNzktMDQ3OC00ODQxLWEzZjMtN2E0Y2MwM2FkMzE0XkEyXkFqcGdeQXVyNTEwNDcxNDc@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1950, 11, 24, 0, 0),
#  'runtime': 103,
#  'title': "King Solomon's Mines",
#  'tomatoes': {'critic': {'meter': 92, 'numReviews': 12, 'rating': 7.2},
#               'dvd': datetime.datetime(2005, 1, 11, 0, 0),
#               'fresh': 11,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 19, 11, 25),
#               'production': 'MGM Home Entertainment',
#               'rotten': 1,
#               'viewer': {'meter': 60, 'numReviews': 3186, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Helen Deutsch (screenplay)', 'H. Rider Haggard (novel)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde7ee'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Errol Flynn', 'Alexis Smith', 'S.Z. Sakall', 'Douglas Kennedy'],
#  'countries': ['USA'],
#  'directors': ['Ray Enright', 'Raoul Walsh'],
#  'fullplot': 'Australian sheep-man Morgan Lane comes to Montana looking for '
#              'government-owned grazing land, and encamps his sheep at the '
#              'boundary line (where the bad grazing ends and the good grazing '
#              'begins) set up by the cattle barons to keep the sheep from '
#              'nubbing away at the good grass. He goes to town, posing as a '
#              'merchant, explains his Australian accent, and learns that Maria '
#              'Singleton, owner of a large ranch, and Rodney Ackroyd (who never '
#              'explains where he got his name), another ranch owner and Miss '
#              "Singleton's fiancèe, are the leaders of the cattlemen against "
#              'the sheep-men. Romance tugs at Morgan and Miss Singleton, who '
#              'quickly decides that Morgan has a much better name than Rodney '
#              '(and other attributes) but the cattle-vs.-sheep feud keeps them '
#              'apart. Until they meet in the street for a showdown gunfight '
#              'following a disastrous clash between the cattle and sheep '
#              'factions.',
#  'genres': ['Action', 'Adventure', 'Romance'],
#  'imdb': {'id': 42744, 'rating': 6.2, 'votes': 759},
#  'languages': ['English'],
#  'lastupdated': '2015-09-17 04:39:05.470000000',
#  'num_mflix_comments': 1,
#  'plot': 'An Australian sheepman comes to Montana looking for grazing space, '
#          'is opposed by local ranchers and a wealthy cattle-woman.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTEyNjI3MTQzMTZeQTJeQWpwZ15BbWU4MDExNjA5MDMx._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1950, 1, 28, 0, 0),
#  'runtime': 76,
#  'title': 'Montana',
#  'tomatoes': {'dvd': datetime.datetime(2008, 8, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 26, 18, 0, 15),
#               'production': 'Warner Home Video',
#               'viewer': {'meter': 30, 'numReviews': 81, 'rating': 2.9}},
#  'type': 'movie',
#  'writers': ['James R. Webb (screenplay)',
#              'Borden Chase (screenplay)',
#              "Charles O'Neal (screenplay)",
#              'Ernest Haycox (story)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcdf12c'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Stewart Granger', 'Eleanor Parker', 'Janet Leigh', 'Mel Ferrer'],
#  'countries': ['USA'],
#  'directors': ['George Sidney'],
#  'fullplot': "Andre-Louis Moreau is a nobleman's bastard in the days of the "
#              'French revolution. Noel, the Marquis de Mayne, a nobleman in '
#              'love with the Queen, is ordered to seek the hand of a young '
#              'ingenue, Aline, in marriage. Andre also meets Aline, and forms '
#              'an interest in her. But when the marquis kills his best friend '
#              "Andre declares himself the Marquis's enemy and vows to avenge "
#              'his friend. He hides out, a wanted man, as an actor in a '
#              'commedia troupe, and spends his days learning how to handle a '
#              'sword. When de Maynes becomes a spadassinicide, challenging '
#              'opposing National Assembly members to duels they have no hope of '
#              'winning, Andre becomes a politician to protect the third estate '
#              '(and hopefully ventilate de Maynes).',
#  'genres': ['Action', 'Adventure', 'Comedy'],
#  'imdb': {'id': 45125, 'rating': 7.7, 'votes': 4112},
#  'languages': ['English'],
#  'lastupdated': '2015-08-23 00:11:05.923000000',
#  'num_mflix_comments': 0,
#  'plot': 'After Andre Moreau finds he is the secret bastard son of a recently '
#          "deceased noble, he realizes that it his own sister that he's "
#          'romantically drawn to.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTYxODY4MzczOV5BMl5BanBnXkFtZTgwMjAyOTYyMjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1952, 6, 27, 0, 0),
#  'runtime': 115,
#  'title': 'Scaramouche',
#  'tomatoes': {'dvd': datetime.datetime(2003, 7, 1, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 13, 19, 16, 27),
#               'production': 'Warner Home Video',
#               'viewer': {'meter': 85, 'numReviews': 2497, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Ronald Millar (screenplay)',
#              'George Froeschel (screenplay)',
#              'Rafael Sabatini (based on the novel by)'],
#  'year': 1952}
# {'_id': ObjectId('573a1394f29313caabcdf340'),
#  'awards': {'nominations': 0,
#             'text': 'Nominated for 1 Oscar. Another 1 win.',
#             'wins': 2},
#  'cast': ['Richard Burton', 'James Mason', 'Robert Newton', 'Robert Douglas'],
#  'countries': ['USA'],
#  'directors': ['Robert Wise'],
#  'fullplot': 'Rommel has the British in retreat on his way to the Suez Canal. '
#              'All that stands in his way is Tobruk, held by a vastly out '
#              'numbered force of Australian troops. Richard Burton leads these '
#              'troops on daring raids against Rommel, keeping him off balance '
#              "as they earn the nickname 'The Desert Rats'.",
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 45679, 'rating': 6.8, 'votes': 3379},
#  'languages': ['English', 'German'],
#  'lastupdated': '2015-08-29 00:03:46.110000000',
#  'num_mflix_comments': 1,
#  'plot': 'Richard Burton plays a Scottish Army officer put in charge of a '
#          'disparate band of ANZAC troops on the perimeter of Tobruk with the '
#          'German Army doing their best to dislodge them.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNjViMWZhYzUtNGM4Ni00ZjQ2LWExNTEtN2M1OTA2NDUyODMwL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjQzNDI3NzY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1953, 5, 20, 0, 0),
#  'runtime': 88,
#  'title': 'The Desert Rats',
#  'tomatoes': {'critic': {'meter': 80, 'numReviews': 5, 'rating': 6.3},
#               'dvd': datetime.datetime(2002, 5, 21, 0, 0),
#               'fresh': 4,
#               'lastUpdated': datetime.datetime(2015, 9, 1, 19, 13, 4),
#               'production': 'Fox',
#               'rotten': 1,
#               'viewer': {'meter': 71, 'numReviews': 1524, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Richard Murphy'],
#  'year': 1953}
# {'_id': ObjectId('573a1394f29313caabcdf465'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 2 Oscars. Another 2 nominations.',
#             'wins': 0},
#  'cast': ['Robert Taylor', 'Ava Gardner', 'Mel Ferrer', 'Anne Crawford'],
#  'countries': ['USA'],
#  'directors': ['Richard Thorpe'],
#  'fullplot': 'King Arthur establishes the greatest reign England has ever '
#              'seen, and along for the ride are his indispensable Knights of '
#              'the Round Table, particularly Sir Lancelot. Then, Arthur finds '
#              'himself a bride, the beautiful Guenivere. While she loves '
#              'Arthur, she also loves Lancelot and though Lancelot repeatedly '
#              'fights it, he loves her, too. Treachery is brewing as the evil '
#              'Morgan le Fay and her knight Sir Modred work to trap them. So '
#              'begins the decline and eventual fall of Arthur and Camelot.',
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 45966, 'rating': 6.3, 'votes': 2262},
#  'languages': ['English'],
#  'lastupdated': '2015-09-13 00:15:19.830000000',
#  'num_mflix_comments': 0,
#  'plot': "King Arthur's rule is threatened by the adulterous love between Sir "
#          "Lancelot and Queen Guinevere, a relationship the king's enemies hope "
#          'to exploit.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjQyMmIyODMtYWU3YS00NTMzLWI3OTAtOWVlNzczMTc1NjQ4XkEyXkFqcGdeQXVyNjQzNDI3NzY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1954, 1, 15, 0, 0),
#  'runtime': 115,
#  'title': 'Knights of the Round Table',
#  'tomatoes': {'critic': {'meter': 80, 'numReviews': 5, 'rating': 6.2},
#               'dvd': datetime.datetime(2003, 7, 1, 0, 0),
#               'fresh': 4,
#               'lastUpdated': datetime.datetime(2015, 8, 4, 20, 11, 1),
#               'production': 'Metro-Goldwyn-Mayer (MGM)',
#               'rotten': 1,
#               'viewer': {'meter': 44, 'numReviews': 2883, 'rating': 3.1}},
#  'type': 'movie',
#  'writers': ['Talbot Jennings (screenplay)',
#              'Jan Lustig (screenplay)',
#              'Noel Langley (screenplay)',
#              'Thomas Malory (based on "Le Morte D\'Arthur")'],
#  'year': 1953}

# %%
#Exercise 2: Sorting Results

#Write a query to find all movies where the genre is "Comedy" and sort them by IMDb
#rating in descending order (Return the first 5 results).
comedies_by_rating = collection.find({"genres": "Comedy"}).sort("imdb.rating", -1).limit(5)
for movie in comedies_by_rating:
    pprint.pprint(movie)

#Write a query to find all movies where the genre is "Drama" and sort them by release year
#in ascending order (Return the first 5 results).
drama_movies_by_year = collection.find({"genres": "Drama"}).sort("year", 1).limit(5)
for movie in drama_movies_by_year:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13dcf29313caabdb2dec'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Jennifer Jason Leigh', 'David Thewlis', 'Tom Noonan'],
#  'countries': ['USA'],
#  'directors': ['Duke Johnson', 'Charlie Kaufman'],
#  'fullplot': "Charlie Kaufman's first stop-motion film about a man crippled by "
#              'the mundanity of his life.',
#  'genres': ['Animation', 'Comedy', 'Fantasy'],
#  'imdb': {'id': 2401878, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:00:23.967000000',
#  'num_mflix_comments': 0,
#  'plot': "Charlie Kaufman's first stop-motion film about a man crippled by the "
#          'mundanity of his life.',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 9, 8, 0, 0),
#  'runtime': 90,
#  'title': 'Anomalisa',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 26, 18, 15, 38),
#               'production': 'Walt Disney Pictures International',
#               'viewer': {'numReviews': 12, 'rating': 2.5}},
#  'type': 'movie',
#  'writers': ['Charlie Kaufman'],
#  'year': 2015}
# {'_id': ObjectId('573a13d9f29313caabdaa62d'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Ray Panthaki', 'Vicky McClure', 'Adeel Akhtar', 'Jenny Bede'],
#  'countries': ['UK'],
#  'directors': ['Keri Collins'],
#  'fullplot': 'Two convenience store robbers mess up the crime and end up '
#              'working there for the rest of the night.',
#  'genres': ['Comedy'],
#  'imdb': {'id': 2263210, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-09-14 17:30:41.583000000',
#  'num_mflix_comments': 0,
#  'plot': 'Two convenience store robbers mess up the crime and end up working '
#          'there for the rest of the night.',
#  'released': datetime.datetime(2015, 10, 2, 0, 0),
#  'title': 'Convenience',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 9, 52, 44),
#               'viewer': {'numReviews': 3, 'rating': 4.0},
#               'website': 'http://www.convenience-movie.com'},
#  'type': 'movie',
#  'writers': ['Simon Fantauzzo'],
#  'year': 2015}
# {'_id': ObjectId('573a13dff29313caabdb909e'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Jessie Barr',
#           'Louis Cancelmi',
#           'Margaret Daly',
#           'Caitlin FitzGerald'],
#  'countries': ['USA'],
#  'directors': ["Tom O'Brien"],
#  'fullplot': 'Danny, a commercial editor and documentary filmmaker attempts to '
#              'finish his film, a study on relationship while navigating the '
#              'relationships in his own life. Will he continue to chase the '
#              'unattainable Theresa a hippy new age dancer(Caitlin Fitzgerald) '
#              "or will he finally admit he's in love with his best friend Carla "
#              '(Katherine Waterston) who is in an unfulfilling relationship '
#              'with a political strategist(Gaby Hoffman). Manhattan Romance is '
#              'a funny insightful look at contemporary life in Manhattan. It '
#              'explores new age ideas and open relationship as well as true '
#              'friendship and connection.',
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 2608324, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-28 00:17:01.610000000',
#  'num_mflix_comments': 0,
#  'plot': 'Danny, a commercial editor and documentary filmmaker attempts to '
#          'finish his film, a study on relationship while navigating the '
#          'relationships in his own life. Will he continue to chase the ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjMzODk2MDc0MF5BMl5BanBnXkFtZTgwMTc3NjU4NjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 10, 2, 0, 0),
#  'runtime': 94,
#  'title': 'Manhattan Romance',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 2, 18, 57, 41),
#               'viewer': {'numReviews': 2, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ["Tom O'Brien"],
#  'year': 2015}
# {'_id': ObjectId('573a13def29313caabdb627d'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Gracie Mei Huntsman',
#           'Jon Huntsman',
#           'Jerome A. Cohen',
#           'Chen Guangcheng'],
#  'countries': ['China', 'USA'],
#  'directors': ['Vanessa Hope'],
#  'genres': ['Documentary', 'Comedy', 'History'],
#  'imdb': {'id': 2505376, 'rating': '', 'votes': ''},
#  'languages': ['English', 'Chinese'],
#  'lastupdated': '2015-08-26 01:05:17.383000000',
#  'num_mflix_comments': 1,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAyNzYzNzIyM15BMl5BanBnXkFtZTgwMjA4ODgxNTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 4, 20, 0, 0),
#  'runtime': 90,
#  'title': 'All Eyes and Ears',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 6, 26, 18, 3, 5),
#               'viewer': {'numReviews': 1, 'rating': 1.5}},
#  'type': 'movie',
#  'writers': ['Vanessa Hope'],
#  'year': 2015}
# {'_id': ObjectId('573a13cff29313caabd88f5b'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Halston Sage',
#           'Tye Sheridan',
#           'Patrick Schwarzenegger',
#           'Cloris Leachman'],
#  'countries': ['USA'],
#  'directors': ['Christopher Landon'],
#  'fullplot': 'Three scouts, on the eve of their last camp-out, discover the '
#              'true meaning of friendship when they attempt to save their town '
#              'from a zombie outbreak.',
#  'genres': ['Comedy', 'Horror'],
#  'imdb': {'id': 1727776, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-27 00:00:19.697000000',
#  'num_mflix_comments': 0,
#  'plot': 'Three scouts, on the eve of their last camp-out, discover the true '
#          'meaning of friendship when they attempt to save their town from a '
#          'zombie outbreak.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY4NjczNjE4OV5BMl5BanBnXkFtZTgwODk0MjQ5NjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 10, 30, 0, 0),
#  'runtime': 93,
#  'title': 'Scouts Guide to the Zombie Apocalypse',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 30, 20, 13, 8),
#               'production': 'Paramount Pictures',
#               'viewer': {'numReviews': 91, 'rating': 2.8},
#               'website': 'http://www.scoutsandzombiesmovie.com/'},
#  'type': 'movie',
#  'writers': ['Emi Mochizuki (screenplay)',
#              'Carrie Lee Wilson (screenplay)',
#              'Christopher Landon (screenplay)',
#              'Lona Williams (screenplay)'],
#  'year': 2015}
# {'_id': ObjectId('573a1394f29313caabcde672'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ["Edmond O'Brien",
#           'Pamela Britton',
#           'Luther Adler',
#           'Beverly Garland'],
#  'countries': ['USA'],
#  'directors': ['Rudolph Matè'],
#  'fullplot': 'Small-town accountant Frank Bigelow goes to San Francisco for a '
#              "week's fun prior to settling down with fiancèe Paula. After a "
#              'night on the town, he wakes up with more than just a hangover; '
#              'doctors tell him he\'s been given a "luminous toxin" with no '
#              'antidote and has, at most, a week to live! Not knowing who did '
#              'it or why, Bigelow embarks on a frantic odyssey to find his own '
#              'murderer.',
#  'genres': ['Drama', 'Film-Noir', 'Mystery'],
#  'imdb': {'id': 42369, 'rating': 7.4, 'votes': 7467},
#  'languages': ['English'],
#  'lastupdated': '2015-08-28 00:12:34.377000000',
#  'num_mflix_comments': 0,
#  'plot': "Frank Bigelow, told he's been poisoned and has only a few days to "
#          'live, tries to find out who killed him and why.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzA1MmY3MzktYWVmYy00Mzc1LWFhNzktNWM0NTRlYjZjZTg2XkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1950, 4, 30, 0, 0),
#  'runtime': 83,
#  'title': 'D.O.A.',
#  'tomatoes': {'critic': {'meter': 95, 'numReviews': 20, 'rating': 7.8},
#               'dvd': datetime.datetime(1950, 4, 30, 0, 0),
#               'fresh': 19,
#               'lastUpdated': datetime.datetime(2015, 8, 15, 19, 0, 17),
#               'production': 'Acme DVD Works',
#               'rotten': 1,
#               'viewer': {'meter': 76, 'numReviews': 2610, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Russell Rouse (story)',
#              'Clarence Greene (story)',
#              'Russell Rouse (screenplay)',
#              'Clarence Greene (screenplay)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde60a'),
#  'awards': {'nominations': 2,
#             'text': 'Nominated for 3 Oscars. Another 2 wins & 2 nominations.',
#             'wins': 5},
#  'cast': ['James Stewart', 'Jeff Chandler', 'Debra Paget', 'Basil Ruysdael'],
#  'countries': ['USA'],
#  'directors': ['Delmer Daves'],
#  'fullplot': 'By 1870, there has been 10 years of cruel war between settlers '
#              "and Cochise's Apaches. Ex-soldier Tom Jeffords saves the life of "
#              'an Apache boy and starts to wonder if Indians are human, after '
#              'all; soon, he determines to use this chance to make himself an '
#              'ambassador. Against all odds, his solitary mission into '
#              "Cochise's stronghold opens a dialogue. Opportunely, the "
#              'president sends General Howard with orders to conclude peace. '
#              "But even with Jeffords's luck, the deep grievance and hatred on "
#              'both sides make tragic failure all too likely.',
#  'genres': ['Drama', 'Romance', 'Western'],
#  'imdb': {'id': 42286, 'rating': 7.3, 'votes': 4930},
#  'languages': ['English', 'Apache languages'],
#  'lastupdated': '2015-09-02 00:36:40.477000000',
#  'num_mflix_comments': 0,
#  'plot': 'Tom Jeffords tries to make peace between settlers and Apaches.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYmI0OGY4MDMtNWFlOS00OTZmLWI0YmQtN2M3YmU5Mjc3MTdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1950, 8, 1, 0, 0),
#  'runtime': 93,
#  'title': 'Broken Arrow',
#  'tomatoes': {'dvd': datetime.datetime(2007, 5, 22, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 14, 22, 10, 25),
#               'production': 'Twentieth Century Fox Home Entertainment',
#               'viewer': {'meter': 71, 'numReviews': 974, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Elliott Arnold (novel)',
#              'Albert Maltz (screenplay)',
#              'Michael Blankfort (front for Albert Maltz)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde5b7'),
#  'awards': {'nominations': 16,
#             'text': 'Won 6 Oscars. Another 17 wins & 16 nominations.',
#             'wins': 23},
#  'cast': ['Bette Davis', 'Anne Baxter', 'George Sanders', 'Celeste Holm'],
#  'countries': ['USA'],
#  'directors': ['Joseph L. Mankiewicz'],
#  'fullplot': 'Aspiring actress Eve Harrington maneuvers her way into the lives '
#              'of Broadway star Margo Channing, playwright Lloyd Richards and '
#              'director Bill Sampson. This classic story of ambition and '
#              'betrayal has become part of American folklore. Bette Davis '
#              'claims to have based her character on the persona of film '
#              'actress Talullah Bankhead. Davis\' line "Fasten your seatbelts, '
#              'it\'s going to be a bumpy night" is legendary, but, in fact, all '
#              "of the film's dialog sparkles with equal brilliance.",
#  'genres': ['Drama'],
#  'imdb': {'id': 42192, 'rating': 8.4, 'votes': 75075},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-09-07 00:00:14.850000000',
#  'num_mflix_comments': 1,
#  'plot': 'An ingenue insinuates herself in to the company of an established '
#          'but aging stage actress and her circle of theater friends.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY2MTAzODI5NV5BMl5BanBnXkFtZTgwMjM4NzQ0MjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1951, 1, 15, 0, 0),
#  'runtime': 138,
#  'title': 'All About Eve',
#  'tomatoes': {'consensus': 'Smart, sophisticated, and devastatingly funny, All '
#                            'About Eve is a Hollywood classic that only '
#                            'improves with age.',
#               'critic': {'meter': 100, 'numReviews': 63, 'rating': 9.1},
#               'dvd': datetime.datetime(1999, 10, 5, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 31, 56),
#               'production': '20th Century Fox',
#               'rotten': 0,
#               'viewer': {'meter': 95, 'numReviews': 43469, 'rating': 4.3}},
#  'type': 'movie',
#  'writers': ['Joseph L. Mankiewicz (written for the screen by)'],
#  'year': 1950}
# {'_id': ObjectId('573a1393f29313caabcde3dc'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Mikheil Gelovani',
#           'Boris Andreyev',
#           'Vladimir Savelyev',
#           'Marina Kovalyova'],
#  'countries': ['Soviet Union'],
#  'directors': ['Mikheil Chiaureli'],
#  'fullplot': 'Surrounded by a few party officials, Alexei Ivanov, a '
#              'stakhanovist smelter, is decorated by Stalin. The "Little Father '
#              'of the Peoples" takes this opportunity to invoke threats of '
#              'war.... One day, war indeed breaks out. Bombs fall on the field '
#              'where Alexei finds himself in the company of the schoolmistress '
#              'Natacha, his fiancèe. Alexei joins the Red Army and soon becomes '
#              'a sergeant. Fighting rages and German troops advance. Natacha is '
#              'arrested and deported. But the tide turns decisively with the '
#              'German defeat at Stalingrad. Now the major offensive against '
#              'Hitler can begin.',
#  'genres': ['Drama', 'War'],
#  'imdb': {'id': 41727, 'rating': 6.3, 'votes': 245},
#  'languages': ['Russian'],
#  'lastupdated': '2015-08-21 00:05:09.983000000',
#  'num_mflix_comments': 0,
#  'plot': 'Surrounded by a few party officials, Alexei Ivanov, a stakhanovist '
#          'smelter, is decorated by Stalin. The "Little Father of the Peoples" '
#          'takes this opportunity to invoke threats of war.... ...',
#  'released': datetime.datetime(1950, 1, 21, 0, 0),
#  'runtime': 167,
#  'title': 'The Fall of Berlin',
#  'tomatoes': {'dvd': datetime.datetime(2007, 2, 27, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 19, 19, 28, 8),
#               'viewer': {'meter': 75, 'numReviews': 37, 'rating': 3.7}},
#  'type': 'movie',
#  'writers': ['Mikheil Chiaureli', 'Pyotr Pavlenko'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde6ab'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Dana Andrews', 'Farley Granger', 'Joan Evans', 'Robert Keith'],
#  'countries': ['USA'],
#  'directors': ['Mark Robson'],
#  'fullplot': 'A poor and alienated young man (Farley Granger) who is driven to '
#              'murder when a priest refuses to give is deceased mother an '
#              'expensive funeral. The film explores the crippling poverty that '
#              'has prevented the youth from marrying or providing his mother '
#              'with enough comforts, and has led to his crime. Dana Andrews '
#              'plays the compassionate assistant of the slain priest who brings '
#              "about the tormented killer's repentance.",
#  'genres': ['Drama', 'Film-Noir'],
#  'imdb': {'id': 42428, 'rating': 6.5, 'votes': 289},
#  'languages': ['English'],
#  'lastupdated': '2015-08-30 00:52:12.447000000',
#  'num_mflix_comments': 1,
#  'plot': "A mentally unbalanced young man kills a priest. One of the priest's "
#          'colleagues sets out to find the killer.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNTc5ODM3Nl5BMl5BanBnXkFtZTYwOTYwMjg5._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1950, 8, 3, 0, 0),
#  'runtime': 99,
#  'title': 'Edge of Doom',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 21, 18, 49, 7),
#               'production': 'Samuel Goldwyn Company',
#               'viewer': {'meter': 22, 'numReviews': 99, 'rating': 3.0}},
#  'type': 'movie',
#  'writers': ['Leo Brady (novel)', 'Philip Yordan'],
#  'year': 1950}

# %%
#Exercise 3: Aggregation Pipeline

#Write an aggregation pipeline that calculates the average IMDb rating for each genre
#(Return the top 5 genres).
pipeline1 = [
    {"$unwind": "$genres"},
    {"$group": {"_id": "$genres", "avg_rating": {"$avg": "$imdb.rating"}}},
    {"$sort": {"avg_rating": -1}},
    {"$limit": 5}
]

avg_rating_by_genre = collection.aggregate(pipeline1)
for genre in avg_rating_by_genre:
    pprint.pprint(genre)

#Write an aggregation pipeline to find the top 5 directors by the average IMDb rating of
#their movies.
pipeline2 = [
    {"$unwind": "$directors"},
    {"$group": {"_id": "$directors", "avg_rating": {"$avg": "$imdb.rating"}}},
    {"$sort": {"avg_rating": -1}},
    {"$limit": 5}
]

avg_rating_by_director = collection.aggregate(pipeline2)
for data in avg_rating_by_director:
    pprint.pprint(data)

#Write an aggregation pipeline to calculate the total number of movies released in each
#year (Sort the results by the year).
pipeline3 = [
    {"$group": {"_id": "$year", "total_movies": {"$sum": 1}}},
    {"$sort": {"_id": 1}}
]

total_movies_per_year = collection.aggregate(pipeline3)
for data in total_movies_per_year:
    pprint.pprint(data)
# Out:
# {'_id': 'Film-Noir', 'avg_rating': 7.396774193548388}
# {'_id': 'Short', 'avg_rating': 7.390625}
# {'_id': 'Documentary', 'avg_rating': 7.365130483064964}
# {'_id': 'News', 'avg_rating': 7.252272727272728}
# {'_id': 'History', 'avg_rating': 7.171942446043165}
# {'_id': 'Sara Hirsh Bordo', 'avg_rating': 9.4}
# {'_id': 'Kevin Derek', 'avg_rating': 9.3}
# {'_id': 'Michael Benson', 'avg_rating': 9.0}
# {'_id': 'Slobodan Sijan', 'avg_rating': 8.95}
# {'_id': 'Sundar C.', 'avg_rating': 8.9}
# {'_id': 1950, 'total_movies': 55}
# {'_id': 1951, 'total_movies': 54}
# {'_id': 1952, 'total_movies': 45}
# {'_id': 1953, 'total_movies': 65}
# {'_id': 1954, 'total_movies': 47}
# {'_id': 1955, 'total_movies': 67}
# {'_id': 1956, 'total_movies': 67}
# {'_id': 1957, 'total_movies': 71}
# {'_id': 1958, 'total_movies': 75}
# {'_id': 1959, 'total_movies': 71}
# {'_id': 1960, 'total_movies': 73}
# {'_id': 1961, 'total_movies': 68}
# {'_id': 1962, 'total_movies': 70}
# {'_id': 1963, 'total_movies': 69}
# {'_id': 1964, 'total_movies': 86}
# {'_id': 1965, 'total_movies': 77}
# {'_id': 1966, 'total_movies': 87}
# {'_id': 1967, 'total_movies': 81}
# {'_id': 1968, 'total_movies': 89}
# {'_id': 1969, 'total_movies': 107}
# {'_id': 1970, 'total_movies': 120}
# {'_id': 1971, 'total_movies': 106}
# {'_id': 1972, 'total_movies': 121}
# {'_id': 1973, 'total_movies': 112}
# {'_id': 1974, 'total_movies': 103}
# {'_id': 1975, 'total_movies': 107}
# {'_id': 1976, 'total_movies': 116}
# {'_id': 1977, 'total_movies': 123}
# {'_id': 1978, 'total_movies': 128}
# {'_id': 1979, 'total_movies': 131}
# {'_id': 1980, 'total_movies': 167}
# {'_id': 1981, 'total_movies': 168}
# {'_id': 1982, 'total_movies': 177}
# {'_id': 1983, 'total_movies': 161}
# {'_id': 1984, 'total_movies': 199}
# {'_id': 1985, 'total_movies': 189}
# {'_id': 1986, 'total_movies': 190}
# {'_id': 1987, 'total_movies': 222}
# {'_id': 1988, 'total_movies': 251}
# {'_id': 1989, 'total_movies': 232}
# {'_id': 1990, 'total_movies': 225}
# {'_id': 1991, 'total_movies': 238}
# {'_id': 1992, 'total_movies': 270}
# {'_id': 1993, 'total_movies': 274}
# {'_id': 1994, 'total_movies': 305}
# {'_id': 1995, 'total_movies': 372}
# {'_id': 1996, 'total_movies': 407}
# {'_id': 1997, 'total_movies': 439}
# {'_id': 1998, 'total_movies': 513}
# {'_id': 1999, 'total_movies': 515}
# {'_id': 2000, 'total_movies': 581}
# {'_id': 2001, 'total_movies': 612}
# {'_id': 2002, 'total_movies': 622}
# {'_id': 2003, 'total_movies': 603}
# {'_id': 2004, 'total_movies': 678}
# {'_id': 2005, 'total_movies': 713}
# {'_id': 2006, 'total_movies': 774}
# {'_id': 2007, 'total_movies': 810}
# {'_id': 2008, 'total_movies': 886}
# {'_id': 2009, 'total_movies': 917}
# {'_id': 2010, 'total_movies': 866}
# {'_id': 2011, 'total_movies': 893}
# {'_id': 2012, 'total_movies': 955}
# {'_id': 2013, 'total_movies': 1105}
# {'_id': 2014, 'total_movies': 1073}
# {'_id': 2015, 'total_movies': 480}
# {'_id': 2016, 'total_movies': 1}
# {'_id': '1981è', 'total_movies': 1}
# {'_id': '1986è', 'total_movies': 1}
# {'_id': '1987è', 'total_movies': 1}
# {'_id': '1988è', 'total_movies': 1}
# {'_id': '1994è1998', 'total_movies': 1}
# {'_id': '1995è', 'total_movies': 1}
# {'_id': '1996è', 'total_movies': 1}
# {'_id': '1997è', 'total_movies': 2}
# {'_id': '1999è', 'total_movies': 1}
# {'_id': '2000è', 'total_movies': 1}
# {'_id': '2002è', 'total_movies': 1}
# {'_id': '2003è', 'total_movies': 1}
# {'_id': '2005è', 'total_movies': 2}
# {'_id': '2006è', 'total_movies': 1}
# {'_id': '2006è2007', 'total_movies': 1}
# {'_id': '2006è2012', 'total_movies': 2}
# {'_id': '2007è', 'total_movies': 3}
# {'_id': '2009è', 'total_movies': 2}
# {'_id': '2010è', 'total_movies': 4}
# {'_id': '2011è', 'total_movies': 2}
# {'_id': '2012è', 'total_movies': 3}
# {'_id': '2014è', 'total_movies': 2}

# %%
#Exercise 4: Updating and Deleting Documents

#Write a query to update the IMDb rating of a movie with the title "The Godfather" to 9.5.
collection.update_one({"title": "The Godfather"}, {"$set": {"imdb.rating": 9.5}})

#Write a query to update all movies where the genre is "Horror" and set their IMDb rating
#to 6.0 if it is currently null.
collection.update_many(
    {"genres": "Horror", "imdb.rating": None},
    {"$set": {"imdb.rating": 6.0}}
)

#Write a query to delete all movies that were released before the year 1950.
collection.delete_many({"year": {"$lt": 1950}})
# Out:
# DeleteResult({'n': 0, 'electionId': ObjectId('7fffffff000000000000011e'), 'opTime': {'ts': Timestamp(1727989907, 7457), 't': 286}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1727989908, 3768), 'signature': {'hash': b'\x8c[<\xb1\x9a6yK\x16H\x8c\xe6FX\x1a\xb6\x10\xf3\xbf`', 'keyId': 7363326094432272385}}, 'operationTime': Timestamp(1727989907, 7457)}, acknowledged=True)

# %%
#Exercise 5: Text Search
#Ensure the title field is indexed for text search in MongoDB and write a query to search
#for movies that contain the word "love" in their title.
collection.drop_indexes()
collection.create_index([("title", "text")])
search_results = collection.find({"$text": {"$search": "love"}})
for result in search_results:
    pprint.pprint(result)

#Write a text search query to find movies where the word "war" appears in the title or plot,
#sorted by IMDb rating (Return only the top 5 results).
collection.drop_indexes()
collection.create_index([("title", "text"), ("plot", "text")])
search_results = collection.find({"$text": {"$search": "war"}}).sort("imdb.rating", -1).limit(5)
for result in search_results:
    pprint.pprint(result)
# Out:
# Streaming output truncated to the last 5000 lines.
#              'accurate, he tells Claude of his plan to kill Flannagan. '
#              "Claude's daughter Ariane overhears the threat and warns Frank of "
#              'the coming trouble. She then plays the part of a worldly '
#              "socialite with a list of conquests as long as Flannagan's. The "
#              "bemused ladies' man returns to America the next day and Ariane, "
#              'completely in love, follows his romantic escapades in the news. '
#              'She sees him again in Paris the following year, and resumes her '
#              'worldly guise, telling tales of former lovers when they meet at '
#              'his hotel in the afternoon. Frank, amazed by the mystery girl '
#              'and surprised to find himself jealous of her past, hires Claude '
#              'to uncover more information about her. When the detective '
#              'realizes what has happened, he asks Frank not to break his '
#              "daughter's heart.",
#  'genres': ['Comedy', 'Romance', 'Drama'],
#  'imdb': {'id': 50658, 'rating': 7.3, 'votes': 9215},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-08-07 01:00:15.787000000',
#  'num_mflix_comments': 2,
#  'plot': 'Director Billy Wilder salutes his idol, Ernst Lubitsch, with this '
#          'comedy about a middle-aged playboy fascinated by the daughter of a '
#          'private detective who has been hired to entrap him with the wife of '
#          'a client.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZDgxMTM4OWQtNjJmMS00YTgwLWI0NjItMWRmMDIwMzQzYTMyXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1957, 6, 30, 0, 0),
#  'runtime': 130,
#  'title': 'Love in the Afternoon',
#  'tomatoes': {'critic': {'meter': 88, 'numReviews': 24, 'rating': 7.1},
#               'dvd': datetime.datetime(2002, 1, 8, 0, 0),
#               'fresh': 21,
#               'lastUpdated': datetime.datetime(2015, 8, 31, 19, 2, 4),
#               'production': 'Twentieth Century Fox Home Entertainment',
#               'rotten': 3,
#               'viewer': {'meter': 79, 'numReviews': 7328, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Billy Wilder (screenplay)',
#              'I.A.L. Diamond (screenplay)',
#              'Claude Anet (novel)'],
#  'year': 1957}
# {'_id': ObjectId('573a1394f29313caabcdfd90'),
#  'awards': {'nominations': 6,
#             'text': 'Won 1 Oscar. Another 1 win & 6 nominations.',
#             'wins': 2},
#  'cast': ['Doris Day', 'James Cagney', 'Cameron Mitchell', 'Robert Keith'],
#  'countries': ['USA'],
#  'directors': ['Charles Vidor'],
#  'fullplot': "In 1920's Chicago, Ruth Etting wants to be a renowned singer, "
#              'which is a far step away from her current work as a taxi dancer. '
#              'Upon walking into the dance hall and seeing her, Chicago '
#              'gangster Marty Snyder immediately falls for Ruth, and works '
#              'toward being her lover, which he believes he can achieve by '
#              'opening up singing opportunities for her. Ruth is initially wary '
#              'of Marty, but makes it clear that she is not interested in him '
#              'in a romantic sense. Regardless, he does help her '
#              'professionally, and through his opportunities, which are '
#              'achieved through intimidation and fear, Ruth does quickly start '
#              'to gain a name as a singer, which she is able to do because of '
#              "her talent and despite Marty's intimidation tactics. However, "
#              'the greater her success, the more reliant she becomes on him. '
#              'This becomes an issue in their relationship as she believes he '
#              'can take her only so far before he becomes a liability, however '
#              'he will never let her go that easily. The one person who tried '
#              'and tries to get Ruth away from her unhappy life with Marty is '
#              'Johnny Alderman, the musical advisor Marty hired for Ruth at the '
#              'first gig he got for her, and who also loves Ruth himself.',
#  'genres': ['Biography', 'Drama', 'Music'],
#  'imdb': {'id': 48317, 'rating': 7.3, 'votes': 2558},
#  'languages': ['English'],
#  'lastupdated': '2015-09-05 00:35:17.287000000',
#  'num_mflix_comments': 1,
#  'plot': 'A fictionalized account of the career of jazz singer Ruth Etting and '
#          'her tempestuous marriage to gangster Marty Snyder, who helped propel '
#          'her to stardom.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzQwZDczMTUtODI3My00ZDkwLWI4ODctMTBkMmRhYjI4Njg3XkEyXkFqcGdeQXVyMjIyNjE2NA@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1955, 6, 10, 0, 0),
#  'runtime': 122,
#  'title': 'Love Me or Leave Me',
#  'tomatoes': {'critic': {'meter': 67, 'numReviews': 6, 'rating': 7.4},
#               'dvd': datetime.datetime(2005, 4, 26, 0, 0),
#               'fresh': 4,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 19, 11, 59),
#               'production': 'MGM Home Entertainment',
#               'rotten': 2,
#               'viewer': {'meter': 76, 'numReviews': 3939, 'rating': 3.5}},
#  'type': 'movie',
#  'writers': ['Daniel Fuchs (screenplay)',
#              'Isobel Lennart (screenplay)',
#              'Daniel Fuchs (story)'],
#  'year': 1955}
# {'_id': ObjectId('573a1394f29313caabcdfd10'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Antonella Lualdi',
#           'Franco Interlenghi',
#           'Sergio Raimondi',
#           'Valeria Moriconi'],
#  'countries': ['Italy', 'France'],
#  'directors': ['Mauro Bolognini'],
#  'fullplot': "The film is about some youths' love stories: Franco and his "
#              'hairdresser girlfriend Adriana, Otello another hairdresser who '
#              'is hopelessly in love with Adriana. The youths usually meet in a '
#              'restaurant whose owner, Ines, seduces Franco making Adriana very '
#              "jealous. In turn the girl decides to accept Otello's courting.",
#  'genres': ['Comedy'],
#  'imdb': {'id': 48207, 'rating': 6.9, 'votes': 90},
#  'languages': ['Italian'],
#  'lastupdated': '2015-07-04 00:38:03.800000000',
#  'num_mflix_comments': 0,
#  'plot': "The film is about some youths' love stories: Franco and his "
#          'hairdresser girlfriend Adriana, Otello another hairdresser who is '
#          'hopelessly in love with Adriana. The youths usually meet in a ...',
#  'released': datetime.datetime(1955, 12, 24, 0, 0),
#  'runtime': 85,
#  'title': 'Wild Love',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 29, 18, 55, 29),
#               'viewer': {'numReviews': 2, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Pasquale Festa Campanile (story)',
#              'Massimo Franciosa (story)',
#              'Pasquale Festa Campanile (screenplay)',
#              'Massimo Franciosa (screenplay)',
#              'Giuseppe Mangione (screenplay)',
#              'Mauro Bolognini (screenplay)'],
#  'year': 1955}
# {'_id': ObjectId('573a13f4f29313caabde1dfd'),
#  'awards': {'nominations': 1, 'text': '2 wins & 1 nomination.', 'wins': 2},
#  'countries': ['South Korea'],
#  'directors': ['Mo-young Jin'],
#  'fullplot': 'A couple who have lived together for 76 years faces the last '
#              'moment of their marriage.',
#  'genres': ['Documentary', 'Family', 'Romance'],
#  'imdb': {'id': 4063314, 'rating': 8.1, 'votes': 69},
#  'languages': ['Korean'],
#  'lastupdated': '2015-08-23 00:50:05.780000000',
#  'num_mflix_comments': 0,
#  'plot': 'A couple who have lived together for 76 years faces the last moment '
#          'of their marriage.',
#  'released': datetime.datetime(2014, 11, 27, 0, 0),
#  'runtime': 86,
#  'title': "My Love, Don't Cross That River",
#  'type': 'movie',
#  'writers': ['Mo-young Jin'],
#  'year': 2014}
# {'_id': ObjectId('573a13f3f29313caabddfd80'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Vivian Sung', 'Bruce Lu-Si Bu', 'Megan Lai', 'Li-Ang Chang'],
#  'countries': ['Taiwan'],
#  'directors': ['Chin-Lin Chiang'],
#  'genres': ['Comedy', 'Drama', 'Fantasy'],
#  'imdb': {'id': 3974790, 'rating': 6.8, 'votes': 462},
#  'languages': ['Mandarin'],
#  'lastupdated': '2015-09-11 00:35:00.010000000',
#  'num_mflix_comments': 0,
#  'released': datetime.datetime(2014, 8, 15, 0, 0),
#  'runtime': 119,
#  'title': 'Cafè. Waiting. Love',
#  'type': 'movie',
#  'writers': ['Giddens Ko (novel)', 'Giddens Ko (screenplay)'],
#  'year': 2014}
# {'_id': ObjectId('573a13eef29313caabdd6ff4'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Dylan Taylor',
#           'Melanie Scrofano',
#           'Meghan Heffern',
#           'Benjamin Ayres'],
#  'countries': ['Canada'],
#  'directors': ['Geordie Sabbagh'],
#  'fullplot': 'A struggling writer meets death and falls in love. He must '
#              'decide if his true love is in this world or the next, and if his '
#              'dreams of success are worth dying for.',
#  'genres': ['Drama', 'Fantasy', 'Romance'],
#  'imdb': {'id': 3611112, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-09-11 00:04:53.430000000',
#  'num_mflix_comments': 0,
#  'plot': 'A struggling writer meets death and falls in love. He must decide if '
#          'his true love is in this world or the next, and if his dreams of '
#          'success are worth dying for.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ1MTQ5ODI2NF5BMl5BanBnXkFtZTgwMzc2MTg0MTE@._V1_SY1000_SX677_AL_.jpg',
#  'runtime': 93,
#  'title': 'A Sunday Kind of Love',
#  'type': 'movie',
#  'writers': ['Geordie Sabbagh', 'Geordie Sabbagh'],
#  'year': 2015}
# {'_id': ObjectId('573a13e7f29313caabdc7aec'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Amy Schumer', 'Sam Rockwell', 'Jimmy Fallon', 'Jon Favreau'],
#  'countries': ['USA'],
#  'directors': ['Kevin Pollak'],
#  'fullplot': 'Over fifty very famous American and Canadian funny people '
#              '(filmmakers, writers, actors and comedians) share life and '
#              'professional journeys and insights, in an effort to shed light '
#              'on the thesis: Do you have to be miserable to be funny?',
#  'genres': ['Documentary', 'Comedy'],
#  'imdb': {'id': 3132632, 'rating': 6.2, 'votes': 442},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 04:22:14.513000000',
#  'metacritic': 51,
#  'num_mflix_comments': 0,
#  'plot': 'Over fifty very famous American and Canadian funny people '
#          '(filmmakers, writers, actors and comedians) share life and '
#          'professional journeys and insights, in an effort to shed light on '
#          'the thesis: Do you have to be miserable to be funny?',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BODM0MjExMzkxNl5BMl5BanBnXkFtZTgwNzM1Mzc3NDE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 4, 14, 0, 0),
#  'runtime': 94,
#  'title': 'Misery Loves Comedy',
#  'tomatoes': {'boxOffice': '$5.2k',
#               'critic': {'meter': 32, 'numReviews': 19, 'rating': 5.3},
#               'dvd': datetime.datetime(2015, 9, 7, 0, 0),
#               'fresh': 6,
#               'lastUpdated': datetime.datetime(2015, 8, 18, 18, 26, 31),
#               'production': 'Tribeca Films',
#               'rotten': 13,
#               'viewer': {'meter': 49, 'numReviews': 263, 'rating': 3.1}},
#  'type': 'movie',
#  'writers': ['Kevin Pollak', 'Kevin Pollak', 'John Vorhaus', 'John Vorhaus'],
#  'year': 2015}
# {'_id': ObjectId('573a13e6f29313caabdc6af3'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Mathieu Amalric', 'Karin Viard', 'Maèwenn', 'Sara Forestier'],
#  'countries': ['France', 'Switzerland', 'Belgium'],
#  'directors': ['Arnaud Larrieu', 'Jean-Marie Larrieu'],
#  'fullplot': 'A literature professor at the University of Lausanne, Marc has a '
#              'reputation for having love affairs with his female students. A '
#              'few days after the disappearance of one of the most brillant of '
#              'these, who was his latest conquest, he encounters Anna who is '
#              'trying to find out more about this beautiful young woman who has '
#              'disappeared.',
#  'genres': ['Crime', 'Thriller'],
#  'imdb': {'id': 3103576, 'rating': 5.9, 'votes': 1044},
#  'languages': ['French'],
#  'lastupdated': '2015-08-22 00:34:30.610000000',
#  'num_mflix_comments': 1,
#  'plot': 'A literature professor at the University of Lausanne, Marc has a '
#          'reputation for having love affairs with his female students. A few '
#          'days after the disappearance of one of the most brillant ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNmFlZmVkZTUtNDdkZS00YjlmLWExNmEtNDMyMjQ1ZmZmZThlXkEyXkFqcGdeQXVyMzU4Nzk4MDI@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 1, 15, 0, 0),
#  'runtime': 110,
#  'title': 'Love Is the Perfect Crime',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 6, 20, 18),
#               'production': 'Gaumont',
#               'viewer': {'numReviews': 60, 'rating': 2.8}},
#  'type': 'movie',
#  'writers': ['Philippe Djian (novel)',
#              'Arnaud Larrieu (screenplay)',
#              'Jean-Marie Larrieu (screenplay)'],
#  'year': 2013}
# {'_id': ObjectId('573a13def29313caabdb6596'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'countries': ['UK'],
#  'directors': ['Sarah McCarthy'],
#  'fullplot': 'ABOUT THE FILM Eleven year old Masha Kulabokhova is about to be '
#              "adopted into fourteen year old Cami Diaz's family. Masha grew up "
#              'in a Russian orphanage; Cami was born and raised in Wisconsin '
#              "and has been the exclusive focus of her parents' love her whole "
#              'life. The process of Masha becoming part of the Diaz family is '
#              'going to change both girls forever. THE DARK MATTER OF LOVE '
#              'follows Masha as she leaves Russia to spend her first year as '
#              'part of the Diaz family, who have also adopted five year old '
#              'twin boys Marcel and Vadim. When the reality of bonding with '
#              'children who have grown up in institutions turns out to be more '
#              "difficult than they ever imagined, the Diaz's hire two of the "
#              "world's best developmental psychologists to help them build "
#              'their new family - through science. Professor Emeritus at the '
#              'University of Virginia School of Medicine, Dr Robert Marvin, has '
#              'spent a lifetime developing a world-renowned therapy program '
#              'that draws upon the past 100 years of scientific discoveries in '
#              "the field of parent child love. By connecting the Diaz's with "
#              'his research, Dr Marvin believes that he can help them create an '
#              'environment in which Masha, Marcel and Vadim can form '
#              'supportive, loving relationships. Sometimes hilarious, sometimes '
#              'heartbreaking, THE DARK MATTER OF LOVE melds the story of the '
#              'Diaz family learning to love, with rare archive footage of '
#              'science experiments exploring parent child love. The science of '
#              'love has an intriguing and dark past. Experiments on monkeys, '
#              "birds and even human children have contributed to science's "
#              "knowledge of love's inner workings. Director Sarah McCarthy "
#              'fuses revealing footage of these experiments to the narrative, '
#              'drawing audiences deeper into the dark matter of love and '
#              'encouraging them to contemplate their own relationships through '
#              'an unflinching, scientific lens.',
#  'genres': ['Documentary'],
#  'imdb': {'id': 2512582, 'rating': 7.4, 'votes': 537},
#  'languages': ['English'],
#  'lastupdated': '2015-08-30 00:48:25.367000000',
#  'num_mflix_comments': 0,
#  'plot': 'Documentary on the psychological aspects of growing up with and '
#          'without parental love. It centers around the Diaz family, who '
#          'chooses to adopt three orphans from Russia, and how their new and '
#          'old kids handle family together.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTg5OTY1MzgwNF5BMl5BanBnXkFtZTgwODIwOTcxMzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2012, 11, 1, 0, 0),
#  'runtime': 93,
#  'title': 'The Dark Matter of Love',
#  'tomatoes': {'dvd': datetime.datetime(2014, 12, 1, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 22, 18, 25, 4),
#               'production': 'Virgil Films',
#               'viewer': {'meter': 79, 'numReviews': 88, 'rating': 3.9},
#               'website': 'http://www.thedarkmatteroflove.com/'},
#  'type': 'movie',
#  'year': 2012}
# {'_id': ObjectId('573a13d5f29313caabd9ddd4'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Frank Dabell'],
#  'countries': ['Germany', 'Italy'],
#  'directors': ['Gustav Hofer', 'Luca Ragazzi'],
#  'fullplot': "After their award winning documentary, 'Suddenly, Last Winter', "
#              'Luca and Gustav are back. This time they have to decide: should '
#              'they stay in Italy, or leave it, like so many of their friends '
#              'have done already. Looking at some defining Italian icons, they '
#              'go on a emotional trip on a old Fiat 500 through Italy, to look '
#              "behind the cliches and to discover, what's left of the famous "
#              'Italian way of life, confronting a glorious pas, a shaky present '
#              'and an uncertain future.',
#  'genres': ['Documentary', 'Adventure', 'Drama'],
#  'imdb': {'id': 2049474, 'rating': 6.5, 'votes': 259},
#  'languages': ['Italian'],
#  'lastupdated': '2015-05-06 00:57:37.703000000',
#  'num_mflix_comments': 0,
#  'plot': "After their award winning documentary, 'Suddenly, Last Winter', Luca "
#          'and Gustav are back. This time they have to decide: should they stay '
#          'in Italy, or leave it, like so many of their ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY0MjU4MDYyMV5BMl5BanBnXkFtZTgwMzkzNzUzMTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2012, 10, 4, 0, 0),
#  'runtime': 75,
#  'title': 'Italy: Love It, or Leave It',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 26, 18, 40, 43),
#               'viewer': {'numReviews': 43, 'rating': 3.5}},
#  'type': 'movie',
#  'writers': ['Gustav Hofer', 'Luca Ragazzi'],
#  'year': 2011}
# {'_id': ObjectId('573a13d3f29313caabd943dd'),
#  'awards': {'nominations': 6, 'text': '4 wins & 6 nominations.', 'wins': 4},
#  'countries': ['USA'],
#  'directors': ['Roger Ross Williams'],
#  'fullplot': 'A powerful exploration of the evangelical campaign to infuse '
#              "African culture with values imported from America's Christian "
#              'Right. The film follows American and Ugandan religious leaders '
#              'fighting sexual immorality and missionaries trying to convince '
#              'Ugandans to follow biblical law.',
#  'genres': ['Documentary'],
#  'imdb': {'id': 1874513, 'rating': 7.5, 'votes': 743},
#  'languages': ['English'],
#  'lastupdated': '2015-08-29 01:07:24.297000000',
#  'metacritic': 77,
#  'num_mflix_comments': 1,
#  'plot': "An account of the American Evangelicals' attempts to indoctrinate "
#          'their Christian Right beliefs in Uganda.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc2NTgwNjY0MV5BMl5BanBnXkFtZTgwNTUzNjMzMDE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2013, 10, 11, 0, 0),
#  'runtime': 83,
#  'title': 'God Loves Uganda',
#  'tomatoes': {'boxOffice': '$48.0k',
#               'critic': {'meter': 100, 'numReviews': 28, 'rating': 7.6},
#               'dvd': datetime.datetime(2014, 5, 19, 0, 0),
#               'fresh': 28,
#               'lastUpdated': datetime.datetime(2015, 8, 2, 18, 29, 26),
#               'production': 'Variance Films',
#               'rotten': 0,
#               'viewer': {'meter': 78, 'numReviews': 2320, 'rating': 3.9},
#               'website': 'http://www.godlovesuganda.com'},
#  'type': 'movie',
#  'writers': ['Benjamin Gray', 'Richard Hankin', 'Roger Ross Williams'],
#  'year': 2013}
# {'_id': ObjectId('573a13d2f29313caabd9264d'),
#  'awards': {'nominations': 3, 'text': '6 wins & 3 nominations.', 'wins': 6},
#  'cast': ['Kat Dennings', 'Chad Michael Murray', 'Rupert Friend', 'Mark Saul'],
#  'countries': ['USA'],
#  'directors': ['Nathan Frankowski'],
#  'fullplot': 'The story follows 19-year-old Renee (Kat Dennings) who has '
#              'always loved fairy tales: the idea of a princess, a hero and a '
#              "happily ever after. But Renee's life is that of a darker tale: "
#              "she's a young woman battling addiction, depression and "
#              'self-injury. In a creative blend of artistic fantasy balanced '
#              'with harsh reality, the movie follows Renee on her courageous '
#              'journey towards recovery.',
#  'genres': ['Biography', 'Drama', 'Music'],
#  'imdb': {'id': 1850418, 'rating': 6.6, 'votes': 1558},
#  'languages': ['English'],
#  'lastupdated': '2015-09-13 03:42:08.357000000',
#  'num_mflix_comments': 0,
#  'plot': 'A drama centered around Renee Yohe and her battle with drugs, '
#          'depression, and other life issues that ultimately leads to the '
#          'founding of charity group To Write Love on Her Arms.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjA2NzQ3MzE1Ml5BMl5BanBnXkFtZTgwNDAxNTI0NDE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2015, 3, 3, 0, 0),
#  'runtime': 118,
#  'title': 'To Write Love on Her Arms',
#  'type': 'movie',
#  'writers': ['Kate King Lynch (screenplay)',
#              'Nathan Frankowski (story)',
#              'Bob Massey (story)',
#              'Josh Lujan Loveless (story)',
#              'Jamie Tworkowski (story)'],
#  'year': 2012}
# {'_id': ObjectId('573a13d2f29313caabd92644'),
#  'awards': {'nominations': 3, 'text': '6 wins & 3 nominations.', 'wins': 6},
#  'cast': ['Kat Dennings', 'Chad Michael Murray', 'Rupert Friend', 'Mark Saul'],
#  'countries': ['USA'],
#  'directors': ['Nathan Frankowski'],
#  'fullplot': 'The story follows 19-year-old Renee (Kat Dennings) who has '
#              'always loved fairy tales: the idea of a princess, a hero and a '
#              "happily ever after. But Renee's life is that of a darker tale: "
#              "she's a young woman battling addiction, depression and "
#              'self-injury. In a creative blend of artistic fantasy balanced '
#              'with harsh reality, the movie follows Renee on her courageous '
#              'journey towards recovery.',
#  'genres': ['Biography', 'Drama', 'Music'],
#  'imdb': {'id': 1850418, 'rating': 6.6, 'votes': 1554},
#  'languages': ['English'],
#  'lastupdated': '2015-09-10 17:11:07.703000000',
#  'num_mflix_comments': 0,
#  'plot': 'A drama centered around Renee Yohe and her battle with drugs, '
#          'depression, and other life issues that ultimately leads to the '
#          'founding of charity group To Write Love on Her Arms.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjA2NzQ3MzE1Ml5BMl5BanBnXkFtZTgwNDAxNTI0NDE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2015, 3, 3, 0, 0),
#  'runtime': 118,
#  'title': 'To Write Love on Her Arms',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 6, 10, 18, 44, 16),
#               'viewer': {'numReviews': 164, 'rating': 3.5}},
#  'type': 'movie',
#  'writers': ['Kate King Lynch (screenplay)',
#              'Nathan Frankowski (story)',
#              'Bob Massey (story)',
#              'Josh Lujan Loveless (story)',
#              'Jamie Tworkowski (story)'],
#  'year': 2012}
# {'_id': ObjectId('573a13cdf29313caabd850f9'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Wes Brown', 'Cheryl Ladd', 'Bruce Boxleitner', 'Julie Mond'],
#  'countries': ['Ireland', 'USA'],
#  'directors': ['Bradford May'],
#  'fullplot': 'A young family struggling to make it on a the western frontier '
#              'decides to allow the wife to work at a seamstress shop. As '
#              'things get better financially, the wife gets sick and passes '
#              'away. With help from his parents the young father learns to deal '
#              'with the tragic loss and threat of losing everything they worked '
#              'so hard for.',
#  'genres': ['Western'],
#  'imdb': {'id': 1672621, 'rating': 6.8, 'votes': 436},
#  'languages': ['English'],
#  'lastupdated': '2015-08-12 00:52:54.487000000',
#  'num_mflix_comments': 0,
#  'plot': "In the early west, a young husband's trials in raising his child "
#          "after his wife's unexpected death.",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMzQ3MDAwNjQwMF5BMl5BanBnXkFtZTcwOTM0MDg3Nw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-PG',
#  'released': datetime.datetime(2011, 10, 1, 0, 0),
#  'runtime': 88,
#  'title': "Love's Resounding Courage",
#  'tomatoes': {'lastUpdated': datetime.datetime(2014, 11, 25, 14, 14, 25),
#               'production': 'Global Universal Pictures',
#               'viewer': {'numReviews': 1, 'rating': 0.5}},
#  'type': 'movie',
#  'writers': ['Kevin Bocarde'],
#  'year': 2011}
# {'_id': ObjectId('573a13ccf29313caabd835e8'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Jane Fonda', 'Catherine Keener', 'Ann Osmond', 'Rbert Bowen Jr.'],
#  'countries': ['USA'],
#  'directors': ['Bruce Beresford'],
#  'fullplot': 'An uptight NYC lawyer takes her two teenagers to her hippie '
#              "mother's farmhouse upstate for a family vacation. What was meant "
#              'to be a weekend getaway quickly turns into a summer adventure of '
#              'romance, music, family secrets and self-discovery.',
#  'genres': ['Comedy', 'Drama', 'Music'],
#  'imdb': {'id': 1649780, 'rating': 5.9, 'votes': 5459},
#  'languages': ['English'],
#  'lastupdated': '2015-09-17 04:42:20.240000000',
#  'metacritic': 45,
#  'num_mflix_comments': 0,
#  'plot': "An uptight NYC lawyer takes her two teenagers to her hippie mother's "
#          'farmhouse upstate for a family vacation.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY1ODAxMzYyNF5BMl5BanBnXkFtZTcwMjQ1MDM3Nw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2012, 8, 16, 0, 0),
#  'runtime': 96,
#  'title': 'Peace, Love, & Misunderstanding',
#  'type': 'movie',
#  'writers': ['Christina Mengert', 'Joseph Muszynski'],
#  'year': 2011}
# {'_id': ObjectId('573a13ccf29313caabd833b4'),
#  'awards': {'nominations': 4, 'text': '1 win & 4 nominations.', 'wins': 1},
#  'cast': ['Maria Annette Tanderè Berglyd',
#           'Otto Garli',
#           'Aurora Bach Rodal',
#           'Vilde Fredriksen Verlo'],
#  'countries': ['Norway'],
#  'directors': ['Anne Sewitsky'],
#  'fullplot': 'A 10-year-old Norwegian girl falls in love for the first time. '
#              'Her friends confront their own feelings as they witness her '
#              'no-holds-barred battle with a rival student for the affections '
#              'of a boy who moves into town.',
#  'genres': ['Family', 'Mystery'],
#  'imdb': {'id': 1648099, 'rating': 7.0, 'votes': 598},
#  'languages': ['Norwegian', 'English'],
#  'lastupdated': '2015-08-31 00:43:23.793000000',
#  'num_mflix_comments': 0,
#  'plot': 'A 10-year-old Norwegian girl falls in love for the first time. Her '
#          'friends confront their own feelings as they witness her '
#          'no-holds-barred battle with a rival student for the affections of a '
#          'boy who moves into town.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTUzNzg3NjA3Ml5BMl5BanBnXkFtZTcwMzc1MTMzNQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2011, 2, 25, 0, 0),
#  'runtime': 83,
#  'title': 'Totally True Love',
#  'type': 'movie',
#  'writers': ['Vigdis Hjorth (novel)', 'Kamilla Krogsveen (screenplay)'],
#  'year': 2011}
# {'_id': ObjectId('573a13ccf29313caabd83278'),
#  'awards': {'nominations': 2, 'text': '1 win & 2 nominations.', 'wins': 1},
#  'cast': ['Clara Augarde', 'Lio', 'Michel Galabru', 'Stefano Cassetti'],
#  'countries': ['France'],
#  'directors': ['Katell Quillèvèrè'],
#  'fullplot': 'Anna a young teenager comes home from her Catholic boarding '
#              'school for the holidays and discovers her father has left. Her '
#              'mother is devastated and confined in the company of the local '
#              'priest, who is also a childhood friend. Anna clings to her '
#              'beloved grandfather. She also grows close to Pierre, a '
#              'free-spirited teenager who cares little about God. Anna is '
#              'preparing for her confirmation, but her budding desire for '
#              'Pierre shakes her faith. She longs to give herself over, body '
#              "and soul... but doesn't know if it is to God, or something else?",
#  'genres': ['Drama'],
#  'imdb': {'id': 1646985, 'rating': 6.5, 'votes': 520},
#  'languages': ['French', 'Italian', 'English'],
#  'lastupdated': '2015-08-09 00:04:39.320000000',
#  'num_mflix_comments': 0,
#  'plot': 'Anna a young teenager comes home from her Catholic boarding school '
#          'for the holidays and discovers her father has left. Her mother is '
#          'devastated and confined in the company of the local ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGM3ZmQ2ZWUtOTdkZC00YzAzLWJhMmEtNWJhMzZhMmMxNzZhXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2010, 8, 4, 0, 0),
#  'runtime': 92,
#  'title': 'Love Like Poison',
#  'type': 'movie',
#  'writers': ['Mariette Dèsert (collaboration)', 'Katell Quillèvèrè'],
#  'year': 2010}
# {'_id': ObjectId('573a13caf29313caabd7d9b2'),
#  'awards': {'nominations': 19,
#             'text': 'Nominated for 1 Golden Globe. Another 4 wins & 19 '
#                     'nominations.',
#             'wins': 5},
#  'cast': ['Steve Carell', 'Ryan Gosling', 'Julianne Moore', 'Emma Stone'],
#  'countries': ['USA'],
#  'directors': ['Glenn Ficarra', 'John Requa'],
#  'fullplot': 'Cal (Steve Carell) and Emily (Julianne Moore) have the perfect '
#              'life together living the American dream... until Emily asks for '
#              'a divorce. Now Cal, Mr Husband, has to navigate the single scene '
#              'with a little help from his professional bachelor friend Jacob '
#              'Palmer (Ryan Gosling). Make that a lot of help...',
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 1570728, 'rating': 7.4, 'votes': 347819},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:01:28.687000000',
#  'metacritic': 68,
#  'num_mflix_comments': 0,
#  'plot': "A middle-aged husband's life changes dramatically when his wife asks "
#          'him for a divorce. He seeks to rediscover his manhood with the help '
#          'of a newfound friend, Jacob, learning to pick up girls at bars.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTg2MjkwMTM0NF5BMl5BanBnXkFtZTcwMzc4NDg2NQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2011, 7, 29, 0, 0),
#  'runtime': 118,
#  'title': 'Crazy, Stupid, Love.',
#  'tomatoes': {'boxOffice': '$84.3M',
#               'consensus': 'It never lives up to the first part of its title, '
#                            "but Crazy, Stupid, Love's unabashed sweetness -- "
#                            'and its terrifically talented cast -- more than '
#                            'make up for its flaws.',
#               'critic': {'meter': 78, 'numReviews': 203, 'rating': 6.9},
#               'dvd': datetime.datetime(2011, 11, 1, 0, 0),
#               'fresh': 158,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 6, 25),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 45,
#               'viewer': {'meter': 77, 'numReviews': 106124, 'rating': 3.8},
#               'website': 'http://www.crazystupidlovemovie.com'},
#  'type': 'movie',
#  'writers': ['Dan Fogelman'],
#  'year': 2011}
# {'_id': ObjectId('573a13c8f29313caabd78c2c'),
#  'awards': {'nominations': 1, 'text': '6 wins & 1 nomination.', 'wins': 6},
#  'cast': ['Mert Firat', 'Saadet Aksoy', 'Emre Karayel', 'Lale Mansur'],
#  'countries': ['Turkey'],
#  'directors': ['Ilksen Basarir'],
#  'fullplot': 'Onur, who has been deaf since birth, works as a librarian. His '
#              'father had left him and his mother when he was seven, and Onur '
#              'has always blamed himself for this. Although being able to '
#              'speak, he has chosen to stay silent because of the pitying looks '
#              "of the people around him. At his friend Vedat's engagement "
#              "party, he meets Zeynep, who later finds out about Onur's hearing "
#              'disability, but is not bothered by it. She is forced by her '
#              'overbearing father to leave home and gets a job at a '
#              'call-center. Having to speak on the phone all day to people she '
#              "doesn't know, Zeynep finds peace with Onur, who she communicates "
#              'with perfectly without speaking...',
#  'genres': ['Drama'],
#  'imdb': {'id': 1513713, 'rating': 7.5, 'votes': 4832},
#  'languages': ['Turkish', 'Sign Languages'],
#  'lastupdated': '2015-08-30 00:42:29.117000000',
#  'num_mflix_comments': 0,
#  'plot': 'Onur, who has been deaf since birth, works as a librarian. His '
#          'father had left him and his mother when he was seven, and Onur has '
#          'always blamed himself for this. Although being able to ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAyODk4Nzc2M15BMl5BanBnXkFtZTcwODg0MDQwOQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2009, 12, 18, 0, 0),
#  'runtime': 98,
#  'title': 'Love in Another Language',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 11, 17, 44, 59),
#               'viewer': {'numReviews': 153, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Ilksen Basarir', 'Mert Firat'],
#  'year': 2009}
# {'_id': ObjectId('573a13c5f29313caabd70e7c'),
#  'awards': {'nominations': 0, 'text': '4 wins.', 'wins': 4},
#  'cast': ['Mao Inoue', 'Masaki Okada', 'Natsuki Harada', 'Keiko Horiuchi'],
#  'countries': ['Japan'],
#  'directors': ['Takehiko Shinjo'],
#  'fullplot': 'As a child Takuma is diagnosed with a heart condition that '
#              'requires care from a cardiologist. He soon becomes friends with '
#              'his doctors young daughter Mayu while being treated at the '
#              'hospital. One day Mayu overhears her father saying that Takumas '
#              'condition is serious enough that he most likely wont live beyond '
#              "the age of 20. Takuma isn't aware of this himself, however, so "
#              'at 8-years-old he makes a promise to marry Mayu when they turn '
#              '20. Later in life, Takuma becomes aware that he wont be able to '
#              'keep this promise and he begins distancing himself from Mayu in '
#              'hopes of protecting her.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 1401656, 'rating': 7.4, 'votes': 1088},
#  'languages': ['Japanese'],
#  'lastupdated': '2015-09-01 00:52:38.583000000',
#  'num_mflix_comments': 1,
#  'plot': 'As a child Takuma is diagnosed with a heart condition that requires '
#          'care from a cardiologist. He soon becomes friends with his doctors '
#          'young daughter Mayu while being treated at the ...',
#  'released': datetime.datetime(2009, 10, 24, 0, 0),
#  'runtime': 122,
#  'title': 'I Give My First Love to You',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 2, 19, 22, 36),
#               'viewer': {'numReviews': 18, 'rating': 4.0}},
#  'type': 'movie',
#  'writers': ['Kotomi Aoki (manga)', 'Kenji Bando (screenplay)'],
#  'year': 2009}
# {'_id': ObjectId('573a13c3f29313caabd6928c'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Elisabeth Badinter', 'Franèois Bayrou', 'Christophe Bigot', 'Cabu'],
#  'countries': ['France'],
#  'directors': ['Daniel Leconte'],
#  'fullplot': 'When twelve cartoons depicting the Prophet Muhammad were '
#              "published by Denmark's largest newspaper in 2005, European "
#              'muslim groups denounced the cartoons as insulting and '
#              "sacrilegious. To everyone's surprise, the protests against the "
#              'Muhammad drawings took a worldwide scale, even leading to '
#              'violent demonstrations in several Muslim countries. In France, '
#              'the satirical news magazine Charlie Hebdo joined the '
#              'conversation and reprinted the controversial cartoons, causing '
#              "an uproar among the country's growing Muslim population. Months "
#              'later, the Great Mosque of Paris, the World Muslim League and '
#              'the Union of Islamic Organizations of France took Charlie '
#              "Hebdo's editor Philippe Val to court for defamation and "
#              'incitement of hatred. Tough Being Loved by Jerks offers a '
#              'real-time account of the ensuing trial, arguably one most '
#              'divisive and heated legal proceedings in recent French history. '
#              'The film features lawyers, witnesses, journalists, editorial '
#              'conferences, demonstrations of support, as well as the reactions '
#              'of the prosecutors and Muslim leaders around the world. Given '
#              'new relevance after the January 7, 2015, attacks at the Charlie '
#              'Hebdo offices, which left 12 dead and 11 wounded, Tough Being '
#              'Loved by Jerks also features candid interviews (and rarely seen '
#              'behind-the-scenes moments) with acclaimed Charlie Hebdo '
#              'cartoonists, such as Cabu, Charb, Tignous and Wolinski, who were '
#              'killed on January 7, 2015. As such, the film offers a unique '
#              "perspective into the current debate around France's founding "
#              'ideals and its current realities.',
#  'genres': ['Documentary'],
#  'imdb': {'id': 1289783, 'rating': 7.0, 'votes': 173},
#  'languages': ['French'],
#  'lastupdated': '2015-08-25 00:53:59.713000000',
#  'num_mflix_comments': 1,
#  'plot': 'When twelve cartoons depicting the Prophet Muhammad were published '
#          "by Denmark's largest newspaper in 2005, European muslim groups "
#          'denounced the cartoons as insulting and sacrilegious. To ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNjEwODQxMjk4Ml5BMl5BanBnXkFtZTgwMzM5NTIxNTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2008, 9, 17, 0, 0),
#  'runtime': 110,
#  'title': "It's Hard Being Loved by Jerks",
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 26, 18, 41, 13),
#               'production': 'Kino Lorber',
#               'viewer': {'meter': 86, 'numReviews': 168, 'rating': 3.6}},
#  'type': 'movie',
#  'year': 2008}
# {'_id': ObjectId('573a13c2f29313caabd68040'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Sarah Jones', 'Haylie Duff', 'Jordan Bridges', 'Cloris Leachman'],
#  'countries': ['USA'],
#  'directors': ['Lou Diamond Phillips'],
#  'fullplot': "This is a Christian film from Janette Oke's Love Comes Softly "
#              'series. Belinda Simpson is recovering from the loss of her '
#              'husband. She arrives in a small Missouri town to become the '
#              "local doctor. The town doesn't immediately take to a female "
#              "doctor. She's also faced with the challenge of an infection in "
#              'the town, that everyone believes came from the local orphanage. '
#              'With the help of her friend, Annie, and a young blacksmith, Lee '
#              'Owens, Belinda seeks a cure.',
#  'genres': ['Western'],
#  'imdb': {'id': 1269560, 'rating': 6.8, 'votes': 778},
#  'languages': ['English'],
#  'lastupdated': '2015-08-12 00:14:35.453000000',
#  'num_mflix_comments': 0,
#  'plot': "This is a Christian film from Janette Oke's Love Comes Softly "
#          'series. Belinda Simpson is recovering from the loss of her husband. '
#          'She arrives in a small Missouri town to become the local ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTgwNDkxMzkzMF5BMl5BanBnXkFtZTcwNjM0Njc0Mg@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-PG',
#  'released': datetime.datetime(2009, 4, 4, 0, 0),
#  'runtime': 88,
#  'title': 'Love Takes Wing',
#  'tomatoes': {'dvd': datetime.datetime(2009, 5, 5, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 1, 19, 31, 38),
#               'viewer': {'meter': 64, 'numReviews': 462, 'rating': 3.9}},
#  'type': 'movie',
#  'writers': ['Rachel Stuhler', 'Janette Oke (book)'],
#  'year': 2009}
# {'_id': ObjectId('573a13c1f29313caabd65e09'),
#  'awards': {'nominations': 9, 'text': '7 wins & 9 nominations.', 'wins': 7},
#  'cast': ['Thora Birch', 'William Black', 'Jimmy Carter', 'Elijah Cummings'],
#  'countries': ['USA'],
#  'directors': ['Michael Moore'],
#  'fullplot': 'Capitalism: A Love Story examines the impact of corporate '
#              'dominance on the everyday lives of Americans (and by default, '
#              'the rest of the world). The film moves from Middle America, to '
#              'the halls of power in Washington, to the global financial '
#              'epicenter in Manhattan. With both humor and outrage, the film '
#              'explores the question: What is the price that America pays for '
#              'its love of capitalism? Families pay the price with their jobs, '
#              'their homes and their savings. Moore goes into the homes of '
#              'ordinary people whose lives have been turned upside down; and he '
#              'goes looking for explanations in Washington, DC and elsewhere. '
#              'What he finds are the all-too-familiar symptoms of a love affair '
#              'gone astray: lies, abuse, betrayal...and 14,000 jobs being lost '
#              'every day. Capitalism: A Love Story also presents what a more '
#              'hopeful future could look like. Who are we and why do we behave '
#              'the way that we do?',
#  'genres': ['Documentary'],
#  'imdb': {'id': 1232207, 'rating': 7.4, 'votes': 32630},
#  'languages': ['English', 'Russian', 'Spanish'],
#  'lastupdated': '2015-09-07 00:44:47.640000000',
#  'metacritic': 61,
#  'num_mflix_comments': 0,
#  'plot': 'An examination of the social costs of corporate interests pursuing '
#          'profits at the expense of the public good.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTYyMTA2MTE4NF5BMl5BanBnXkFtZTcwNTgwMDE4Mg@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2009, 10, 2, 0, 0),
#  'runtime': 127,
#  'title': 'Capitalism: A Love Story',
#  'tomatoes': {'boxOffice': '$14.3M',
#               'consensus': 'Love him or hate him, Capitalism captures Michael '
#                            'Moore in his muckraking element -- with all the '
#                            'Moore-centric showmanship that entails.',
#               'critic': {'meter': 75, 'numReviews': 178, 'rating': 6.7},
#               'dvd': datetime.datetime(2010, 3, 9, 0, 0),
#               'fresh': 133,
#               'lastUpdated': datetime.datetime(2015, 8, 21, 18, 31, 22),
#               'production': 'Overture Films',
#               'rotten': 45,
#               'viewer': {'meter': 73, 'numReviews': 70389, 'rating': 3.6},
#               'website': 'http://www.capitalismalovestory.com/'},
#  'type': 'movie',
#  'writers': ['Michael Moore'],
#  'year': 2009}
# {'_id': ObjectId('573a13bff29313caabd5fca1'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Natalie Portman', 'Makram Khoury', 'Shira Haas', 'Gilad Kahana'],
#  'countries': ['Israel'],
#  'directors': ['Natalie Portman'],
#  'fullplot': 'A drama based on the memoir of Amos Oz, a writer, journalist, '
#              'and advocate of a two-state solution to the Israeli-Palestinian '
#              'conflict.',
#  'genres': ['Drama'],
#  'imdb': {'id': 1135989, 'rating': 5.5, 'votes': 121},
#  'languages': ['Hebrew'],
#  'lastupdated': '2015-08-20 00:05:14.187000000',
#  'metacritic': 51,
#  'num_mflix_comments': 0,
#  'plot': 'A drama based on the memoir of Amos Oz, a writer, journalist, and '
#          'advocate of a two-state solution to the Israeli-Palestinian '
#          'conflict.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjIyNzk2MTY0Ml5BMl5BanBnXkFtZTgwMzExNTA2OTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 5, 16, 0, 0),
#  'runtime': 95,
#  'title': 'A Tale of Love and Darkness',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 22, 19, 5, 31),
#               'viewer': {'numReviews': 25, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Amos Oz (memoir)', 'Natalie Portman (screenplay)'],
#  'year': 2015}
# {'_id': ObjectId('573a13bff29313caabd5ec26'),
#  'awards': {'nominations': 5, 'text': '5 wins & 5 nominations.', 'wins': 5},
#  'cast': ['Rolf Kristian Larsen',
#           'Arthur Berning',
#           'Ida Elise Broch',
#           'Ole Christoffer Ertvaag'],
#  'countries': ['Norway'],
#  'directors': ['Stian Kristiansen'],
#  'fullplot': "It's November 1989, and the Berlin Wall is falling. In "
#              'Stavanger, Norway, teenage boy Jarle has a great new girlfriend '
#              'and is starting a rock band with his buddies. But when a new '
#              'boy, the synth pop-listening Yngve, joins his class, Jarle is '
#              'more fascinated than he wants to be, and the world as he knows '
#              'it starts to crumble.',
#  'genres': ['Comedy', 'Drama', 'Music'],
#  'imdb': {'id': 1114723, 'rating': 7.1, 'votes': 3168},
#  'languages': ['Norwegian'],
#  'lastupdated': '2015-08-30 00:12:56.197000000',
#  'num_mflix_comments': 0,
#  'plot': 'A teenage boy loses his footing when he finds himself drawn to the '
#          'new boy in class.',
#  'released': datetime.datetime(2008, 2, 15, 0, 0),
#  'runtime': 90,
#  'title': 'The Man Who Loved Yngve',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 26, 18, 0, 39),
#               'viewer': {'meter': 79, 'numReviews': 1814, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Tore Renberg (novel)', 'Tore Renberg (screenplay)'],
#  'year': 2008}
# {'_id': ObjectId('573a13c0f29313caabd6100e'),
#  'awards': {'nominations': 1, 'text': '3 wins & 1 nomination.', 'wins': 3},
#  'cast': ['Brad Ashby', 'Mia Wasikowska', 'Vladimir Matovic', 'Beau South'],
#  'countries': ['Australia'],
#  'directors': ['Spencer Susser'],
#  'fullplot': 'Jimbo is thirteen and he has a crush on Sarah Jane, the girl of '
#              "his dreams. She still doesn't want to hear of him. But Jimbo is "
#              'persistent. He will make Sarah Jane fall for him, no matter how '
#              'long it must take. And what does he care if he lives in a '
#              'post-apocalyptic environment? If all the adults are dead? If the '
#              "place is infested with zombies? Jimbo loves Sarah Jane. That's "
#              'that.',
#  'genres': ['Short', 'Horror', 'Romance'],
#  'imdb': {'id': 1157658, 'rating': 7.1, 'votes': 1017},
#  'languages': ['English'],
#  'lastupdated': '2015-08-05 01:25:49.257000000',
#  'num_mflix_comments': 0,
#  'plot': 'Jimbo is 13 and can think of only one girl -- Sarah Jane. And no '
#          'matter what stands in his way-bullies, violence, chaos, or '
#          'zombies-nothing will stop him from finding a way into her world.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNjQ4NjY5Njg5OV5BMl5BanBnXkFtZTgwNTcyODExMTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2008, 1, 1, 0, 0),
#  'runtime': 14,
#  'title': 'I Love Sarah Jane',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 22, 18, 1, 39),
#               'viewer': {'numReviews': 487, 'rating': 4.0}},
#  'type': 'movie',
#  'writers': ['David Michèd', 'Spencer Susser'],
#  'year': 2008}
# {'_id': ObjectId('573a13bff29313caabd60945'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Bill Alexander', 'Maude Barlow', 'Basil Bold', 'Shelly Brime'],
#  'countries': ['USA'],
#  'directors': ['Irena Salina'],
#  'fullplot': 'Water is the very essence of life, sustaining every being on the '
#              "planet. 'Flow' confronts the disturbing reality that our crucial "
#              'resource is dwindling and greed just may be the cause.',
#  'genres': ['Documentary'],
#  'imdb': {'id': 1149583, 'rating': 7.6, 'votes': 1008},
#  'languages': ['English'],
#  'lastupdated': '2015-08-19 00:19:39.360000000',
#  'metacritic': 67,
#  'num_mflix_comments': 0,
#  'plot': 'Water is the very essence of life, sustaining every being on the '
# ...
#  'tomatoes': {'dvd': datetime.datetime(2000, 2, 22, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 9, 19, 32, 3),
#               'viewer': {'meter': 35, 'numReviews': 5894, 'rating': 3.0}},
#  'type': 'movie',
#  'writers': ['Yiu Ming Leung (screenplay)',
#              'Foo Ho Tai (screenplay)',
#              'Hark Tsui'],
#  'year': 1989}
# {'_id': ObjectId('573a13b6f29313caabd4842b'),
#  'awards': {'nominations': 3, 'text': '1 win & 3 nominations.', 'wins': 1},
#  'countries': ['USA'],
#  'directors': ['Jake Clennell'],
#  'fullplot': "Welcome to The Great Happiness Space: Rakkyo Cafè. The club's "
#              'owner, Issei (22), has a staff of twenty boys all under his '
#              "training to become the top escorts of Osaka's underground love "
#              'scene. During their training, they learn how to dress, how to '
#              'talk, how to walk, and most importantly, how to fake '
#              'relationships with the girls who become their source of income. '
#              "Join us as Osaka's number one host boy takes us on a journey "
#              'through the complex and heartrenching world of love for sale in '
#              'the Japanese underground.',
#  'genres': ['Documentary'],
#  'imdb': {'id': 493420, 'rating': 7.9, 'votes': 1195},
#  'languages': ['Japanese', 'English'],
#  'lastupdated': '2015-09-14 07:21:28.433000000',
#  'num_mflix_comments': 0,
#  'plot': "Welcome to The Great Happiness Space: Rakkyo Cafè. The club's owner, "
#          'Issei (22), has a staff of twenty boys all under his training to '
#          "become the top escorts of Osaka's underground love ...",
#  'released': datetime.datetime(2006, 1, 22, 0, 0),
#  'runtime': 76,
#  'title': 'The Great Happiness Space: Tale of an Osaka Love Thief',
#  'tomatoes': {'dvd': datetime.datetime(2007, 8, 13, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 6, 7, 18, 11, 38),
#               'viewer': {'meter': 88, 'numReviews': 1608, 'rating': 4.0}},
#  'type': 'movie',
#  'year': 2006}
# {'_id': ObjectId('573a1395f29313caabce1f02'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 4 Oscars. Another 15 wins & 4 nominations.',
#             'wins': 19},
#  'cast': ['Peter Sellers', 'George C. Scott', 'Sterling Hayden', 'Keenan Wynn'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Stanley Kubrick'],
#  'fullplot': 'Paranoid Brigadier General Jack D. Ripper of Burpelson Air Force '
#              'Base, he believing that fluoridation of the American water '
#              'supply is a Soviet plot to poison the U.S. populace, is able to '
#              'deploy through a back door mechanism a nuclear attack on the '
#              'Soviet Union without the knowledge of his superiors, including '
#              'the Chair of the Joint Chiefs of Staff, General Buck Turgidson, '
#              'and President Merkin Muffley. Only Ripper knows the code to '
#              'recall the B-52 bombers and he has shut down communication in '
#              'and out of Burpelson as a measure to protect this attack. '
#              "Ripper's executive officer, RAF Group Captain Lionel Mandrake "
#              '(on exchange from Britain), who is being held at Burpelson by '
#              'Ripper, believes he knows the recall codes if he can only get a '
#              'message to the outside world. Meanwhile at the Pentagon War '
#              'Room, key persons including Muffley, Turgidson and nuclear '
#              'scientist and adviser, a former Nazi named Dr. Strangelove, are '
#              'discussing measures to stop the attack or mitigate its blow-up '
#              'into an all out nuclear war with the Soviets. Against '
#              "Turgidson's wishes, Muffley brings Soviet Ambassador Alexi de "
#              'Sadesky into the War Room, and get his boss, Soviet Premier '
#              "Dimitri Kisov, on the hot line to inform him of what's going on. "
#              'The Americans in the War Room are dismayed to learn that the '
#              'Soviets have a yet as unannounced Doomsday Device to detonate if '
#              'any of their key targets are hit. As Ripper, Mandrake and those '
#              'in the War Room try and work the situation to their end goal, '
#              'Major T.J. "King" Kong, one of the B-52 bomber pilots, is '
#              'working on his own agenda of deploying his bomb where ever he '
#              "can on enemy soil if he can't make it to his intended target.",
#  'genres': ['Comedy', 'War'],
#  'imdb': {'id': 57012, 'rating': 8.5, 'votes': 312300},
#  'languages': ['English', 'Russian'],
#  'lastupdated': '2015-09-07 00:02:44.187000000',
#  'metacritic': 96,
#  'num_mflix_comments': 1,
#  'plot': 'An insane general triggers a path to nuclear holocaust that a war '
#          'room full of politicians and generals frantically try to stop.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZWI3ZTMxNjctMjdlNS00NmUwLWFiM2YtZDUyY2I3N2MxYTE0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1964, 1, 29, 0, 0),
#  'runtime': 95,
#  'title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the '
#           'Bomb',
#  'tomatoes': {'consensus': "Stanley Kubrick's brilliant Cold War satire "
#                            'remains as funny and razor-sharp today as it was '
#                            'in 1964.',
#               'critic': {'meter': 99, 'numReviews': 68, 'rating': 9.0},
#               'dvd': datetime.datetime(2004, 11, 2, 0, 0),
#               'fresh': 67,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 1, 26),
#               'production': 'Sony Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 94, 'numReviews': 205971, 'rating': 4.2}},
#  'type': 'movie',
#  'writers': ['Stanley Kubrick (screenplay)',
#              'Terry Southern (screenplay)',
#              'Peter George (screenplay)',
#              'Peter George (based on the book: "Red Alert" by)'],
#  'year': 1964}
# {'_id': ObjectId('573a13c1f29313caabd642ea'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Christine Bernsten',
#           'Eric DiIlio',
#           'Frank DiMarco',
#           'Jason T. Edwards'],
#  'countries': ['USA'],
#  'directors': ['Ian McCluskey'],
#  'fullplot': 'She was beautiful, smart, and searching. He was an emerging '
#              'genius in the world of photography. When they met, they fell '
#              'instantly in love. Setting off across the West with camera and '
#              'typewriter in the depths of the Great Depression, Charis Wilson '
#              'and Edward Weston transformed photography, and each other. Now '
#              'age 90, Charis Wilson recounts her years with Weston with great '
#              'humor, candor, and some regret. Combining insight from leading '
#              'scholars, rare archival images, and convincingly authentic '
#              'reenactments, Eloquent Nude presents a remarkable true story of '
#              'love and loss, travel and adventure, and an intimate look at the '
#              'making of Modern photography.',
#  'genres': ['Documentary', 'Biography'],
#  'imdb': {'id': 1204893, 'rating': 8.3, 'votes': 38},
#  'languages': ['English'],
#  'lastupdated': '2015-09-13 14:11:00.120000000',
#  'num_mflix_comments': 1,
#  'plot': 'She was beautiful, smart, and searching. He was an emerging genius '
#          'in the world of photography. When they met, they fell instantly in '
#          'love. Setting off across the West with camera and ...',
#  'released': datetime.datetime(2007, 10, 27, 0, 0),
#  'runtime': 57,
#  'title': 'Eloquent Nude: The Love and Legacy of Edward Weston & Charis Wilson',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 28, 18, 35, 34),
#               'viewer': {'numReviews': 243, 'rating': 3.9}},
#  'type': 'movie',
#  'year': 2007}
# {'_id': ObjectId('573a13eef29313caabdd676a'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Joe Berry', 'Uncle Bob', 'Sam Doungaphay', 'Sokmakara Hang'],
#  'countries': ['USA'],
#  'directors': ['Sara Dosa'],
#  'fullplot': 'In search of the lucrative matsutake mushroom, two former '
#              'soldiers discover the means to gradually heal their wounds of '
#              "war. Roger, a self-described 'fall-down drunk' and sniper in "
#              'Vietnam, and Kouy, a Cambodian refugee who fought the Khmer '
#              'Rouge, bonded in the bustling tent-city known as Mushroom Camp, '
#              'which pops up each autumn in the Oregon woods. Their friendship '
#              'became an adoptive family; according to a Cambodian custom, if '
#              'you lose your family like Kouy, you must rebuilt it anew. Now, '
#              "however, this new family could be lost. Roger's health is "
#              'declining and trauma flashbacks rack his mind; Kouy gently aids '
#              'his family before the snow falls and the hunting season ends, '
#              'signaling his time to leave.',
#  'genres': ['Documentary', 'Family', 'War'],
#  'imdb': {'id': 3593932, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2014-09-20 04:04:23.547000000',
#  'num_mflix_comments': 1,
#  'plot': 'In search of the lucrative matsutake mushroom, two former soldiers '
#          'discover the means to gradually heal their wounds of war. Roger, a '
#          "self-described 'fall-down drunk' and sniper in Vietnam,...",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY2NDYzNDcyOF5BMl5BanBnXkFtZTgwNTAxNjkyMjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 4, 25, 0, 0),
#  'runtime': 78,
#  'title': 'The Last Season',
#  'type': 'movie',
#  'year': 2014}
# {'_id': ObjectId('573a13f2f29313caabddcf5f'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Pilou Asbèk', 'Tuva Novotny', 'Sèren Malling', 'Dar Salim'],
#  'countries': ['Denmark'],
#  'directors': ['Tobias Lindholm'],
#  'fullplot': 'Company commander Claus M. Pedersen (Pilou Asbèk) and his men '
#              'are stationed in an Afghan province. Meanwhile back in Denmark '
#              "Claus' wife Maria (Tuva Novotny) is trying to hold everyday life "
#              'together with a husband at war and three children missing their '
#              'father. During a routine mission, the soldiers are caught in '
#              'heavy crossfire and in order to save his men, Claus makes a '
#              'decision that has grave consequences for him - and his family '
#              'back home.',
#  'genres': ['Drama', 'War'],
#  'imdb': {'id': 3830162, 'rating': '', 'votes': ''},
#  'languages': ['Danish'],
#  'lastupdated': '2015-09-05 00:28:23.783000000',
#  'num_mflix_comments': 0,
#  'plot': 'Company commander Claus M. Pedersen (Pilou Asbèk) and his men are '
#          "stationed in an Afghan province. Meanwhile back in Denmark Claus' "
#          'wife Maria (Tuva Novotny) is trying to hold everyday life...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjA1ODY3NjQzNV5BMl5BanBnXkFtZTgwNjEzNTUxNzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 9, 10, 0, 0),
#  'title': 'A War',
#  'type': 'movie',
#  'writers': ['Tobias Lindholm'],
#  'year': 2015}
# {'_id': ObjectId('573a13e2f29313caabdbe708'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Robert Pattinson',
#           'Liam Cunningham',
#           'Stacy Martin',
#           'Bèrènice Bejo'],
#  'countries': ['France'],
#  'directors': ['Brady Corbet'],
#  'fullplot': 'This chilling fable about the rise of fascism in the 20th '
#              'Century tells the story of a young American boy living in France '
#              'in 1918 whose father is working for the US government on the '
#              'creation of the Treaty of Versailles. What he witnesses helps to '
#              'mould his beliefs - and we witness the birth of a terrifying '
#              'ego. Loosely inspired by the early childhood experiences of many '
#              'of the great dictators of the 20th Century and infused with the '
#              'same sense of dread as The Others and The Omen, The Childhood of '
#              'a Leader is an ominous portrait of emerging evil.',
#  'genres': ['Drama', 'Horror', 'Mystery'],
#  'imdb': {'id': 2815902, 'rating': '', 'votes': ''},
#  'lastupdated': '2015-08-31 00:00:22.140000000',
#  'num_mflix_comments': 1,
#  'plot': 'A look at the childhood life of a a post-World War I leader.',
#  'title': 'The Childhood of a Leader',
#  'tomatoes': {'lastUpdated': datetime.datetime(2014, 11, 16, 2, 47, 43),
#               'viewer': {'numReviews': 0, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Brady Corbet (screenplay)', 'Mona Fastvold'],
#  'year': 2015}
# {'_id': ObjectId('573a1398f29313caabcebc0b'),
#  'awards': {'nominations': 3,
#             'text': 'Won 2 Primetime Emmys. Another 8 wins & 3 nominations.',
#             'wins': 10},
#  'cast': ['Sam Waterston', 'Julie Harris', 'Jason Robards', 'Morgan Freeman'],
#  'countries': ['USA'],
#  'fullplot': 'This highly acclaimed mini series traces the course of the U.S. '
#              'Civil War from the abolitionist movement through all the major '
#              'battles to the death of President Lincoln and the beginnings of '
#              'Reconstruction. The story is mostly told in the words of the '
#              'participants themselves, through their diaries, letters, and '
#              'Visuals are usually still photographs and illustrations of the '
#              'time, and the soundtrack is likewise made up of war-era tunes '
#              'played on period instruments. Several modern-day historians '
#              "offer periodic comment and insight on the war's causes and "
#              'events.',
#  'genres': ['Documentary', 'History', 'War'],
#  'imdb': {'id': 98769, 'rating': 9.4, 'votes': 4625},
#  'languages': ['English'],
#  'lastupdated': '2015-09-01 00:13:15.693000000',
#  'num_mflix_comments': 1,
#  'plot': 'A comprehensive survey of the American Civil War.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZDc1NzI2MGEtZDA2Yy00ZWExLTgwYmItNjU3N2QyYmM0MzYwXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1990, 9, 23, 0, 0),
#  'runtime': 680,
#  'title': 'The Civil War',
#  'tomatoes': {'dvd': datetime.datetime(2006, 1, 10, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 25, 19, 21, 52),
#               'production': 'Pet Fly Productions',
#               'viewer': {'meter': 56, 'numReviews': 466, 'rating': 3.2}},
#  'type': 'series',
#  'year': 1990}
# {'_id': ObjectId('573a13a3f29313caabd0e77b'),
#  'awards': {'nominations': 3,
#             'text': 'Won 2 Primetime Emmys. Another 8 wins & 3 nominations.',
#             'wins': 10},
#  'cast': ['Sam Waterston', 'Julie Harris', 'Jason Robards', 'Morgan Freeman'],
#  'countries': ['USA'],
#  'fullplot': 'This highly acclaimed mini series traces the course of the U.S. '
#              'Civil War from the abolitionist movement through all the major '
#              'battles to the death of President Lincoln and the beginnings of '
#              'Reconstruction. The story is mostly told in the words of the '
#              'participants themselves, through their diaries, letters, and '
#              'Visuals are usually still photographs and illustrations of the '
#              'time, and the soundtrack is likewise made up of war-era tunes '
#              'played on period instruments. Several modern-day historians '
#              "offer periodic comment and insight on the war's causes and "
#              'events.',
#  'genres': ['Documentary', 'History', 'War'],
#  'imdb': {'id': 98769, 'rating': 9.4, 'votes': 4624},
#  'languages': ['English'],
#  'lastupdated': '2015-08-30 22:52:05.467000000',
#  'num_mflix_comments': 0,
#  'plot': 'A comprehensive survey of the American Civil War.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZDc1NzI2MGEtZDA2Yy00ZWExLTgwYmItNjU3N2QyYmM0MzYwXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1990, 9, 23, 0, 0),
#  'runtime': 680,
#  'title': 'The Civil War',
#  'type': 'series',
#  'year': 1990}
